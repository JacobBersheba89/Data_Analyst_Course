# %% [markdown]
# # Exercise 1
#
# Using the `requests` library retrieve the current exchange rates served by the API at [http://api.nbp.pl/api/exchangerates/tables/a/](http://api.nbp.pl/api/exchangerates/tables/a/), and display them in a column like this:
#
# ```
# AUD (Australian dollar): 2.8571 PLN
# USD (United States dollar): 3.8849 PLN
# ```
#
# Sometimes the API can return very complicated data. In this case the endpoint returns a table. Example data (in the example we do not show all currencies):
# ```
# [
#     {
#         "effectiveDate": "2021-07-28",
#         "no": "144/A/NBP/2021",
#         "rates": [
#             {
#                 "code": "THB",
#                 "currency": "bat (Tajlandia)",
#                 "mid": 0.1182
#             },
#             {
#                 "code": "XDR",
#                 "currency": "SDR (MFW)",
#                 "mid": 5.5302
#             }
#         ],
#         "table": "A"
#     }
# ]
# ```
#
# To analyze the data returned from an endpoint, you can easily use the following piece of code:
# ```
# import json
# import requests
#
# response = requests.get('http://api.nbp.pl/api/exchangerates/tables/a/')
# data = response.json()
#
# print(json.dumps(data, indent=4, sort_keys=True))
# ```

# %%
import requests

# URL of the API to retrieve exchange rates
url = "http://api.nbp.pl/api/exchangerates/tables/a/"

# Retrieve the data using the requests library
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Parse the JSON response
    data = response.json()

    # Access the rates from the first element in the list
    rates = data[0]["rates"]

    # Print each rate in the specified format
    for rate in rates:
        currency_code = rate["code"]
        currency_name = rate["currency"].capitalize()
        exchange_rate = rate["mid"]
        print(f"{currency_code} ({currency_name}): {exchange_rate} PLN")
else:
    print(f"Failed to retrieve data from the API. Status code: {response.status_code}")
# Out:
# THB (Bat (tajlandia)): 0.1184 PLN
# USD (Dolar amerykański): 3.8368 PLN
# AUD (Dolar australijski): 2.6422 PLN
# HKD (Dolar hongkongu): 0.4934 PLN
# CAD (Dolar kanadyjski): 2.8458 PLN
# NZD (Dolar nowozelandzki): 2.4207 PLN
# SGD (Dolar singapurski): 2.9906 PLN
# EUR (Euro): 4.2761 PLN
# HUF (Forint (węgry)): 0.010775 PLN
# CHF (Frank szwajcarski): 4.5396 PLN
# GBP (Funt szterling): 5.1312 PLN
# UAH (Hrywna (ukraina)): 0.0932 PLN
# JPY (Jen (japonia)): 0.026805 PLN
# CZK (Korona czeska): 0.1699 PLN
# DKK (Korona duńska): 0.5735 PLN
# ISK (Korona islandzka): 0.028375 PLN
# NOK (Korona norweska): 0.3639 PLN
# SEK (Korona szwedzka): 0.3788 PLN
# RON (Lej rumuński): 0.8594 PLN
# BGN (Lew (bułgaria)): 2.1863 PLN
# TRY (Lira turecka): 0.1122 PLN
# ILS (Nowy izraelski szekel): 1.0352 PLN
# CLP (Peso chilijskie): 0.004256 PLN
# PHP (Peso filipińskie): 0.0684 PLN
# MXN (Peso meksykańskie): 0.1964 PLN
# ZAR (Rand (republika południowej afryki)): 0.2235 PLN
# BRL (Real (brazylia)): 0.7056 PLN
# MYR (Ringgit (malezja)): 0.9312 PLN
# IDR (Rupia indonezyjska): 0.00025368 PLN
# INR (Rupia indyjska): 0.045848 PLN
# KRW (Won południowokoreański): 0.002922 PLN
# CNY (Yuan renminbi (chiny)): 0.5471 PLN
# XDR (Sdr (mfw)): 5.1889 PLN

# %%
import json
import requests

# Retrieve the data from the API
response = requests.get('http://api.nbp.pl/api/exchangerates/tables/a/')

# Check if the response was successful
if response.status_code == 200:
    # Parse the JSON response
    data = response.json()
    
    # Use json.dumps to pretty print the data with indentation and sorted keys
    print(json.dumps(data, indent=4, sort_keys=True))
else:
    print(f"Failed to retrieve data. Status code: {response.status_code}")
# Out:
# [
#     {
#         "effectiveDate": "2024-09-27",
#         "no": "189/A/NBP/2024",
#         "rates": [
#             {
#                 "code": "THB",
#                 "currency": "bat (Tajlandia)",
#                 "mid": 0.1184
#             },
#             {
#                 "code": "USD",
#                 "currency": "dolar ameryka\u0144ski",
#                 "mid": 3.8368
#             },
#             {
#                 "code": "AUD",
#                 "currency": "dolar australijski",
#                 "mid": 2.6422
#             },
#             {
#                 "code": "HKD",
#                 "currency": "dolar Hongkongu",
#                 "mid": 0.4934
#             },
#             {
#                 "code": "CAD",
#                 "currency": "dolar kanadyjski",
#                 "mid": 2.8458
#             },
#             {
#                 "code": "NZD",
#                 "currency": "dolar nowozelandzki",
#                 "mid": 2.4207
#             },
#             {
#                 "code": "SGD",
#                 "currency": "dolar singapurski",
#                 "mid": 2.9906
#             },
#             {
#                 "code": "EUR",
#                 "currency": "euro",
#                 "mid": 4.2761
#             },
#             {
#                 "code": "HUF",
#                 "currency": "forint (W\u0119gry)",
#                 "mid": 0.010775
#             },
#             {
#                 "code": "CHF",
#                 "currency": "frank szwajcarski",
#                 "mid": 4.5396
#             },
#             {
#                 "code": "GBP",
#                 "currency": "funt szterling",
#                 "mid": 5.1312
#             },
#             {
#                 "code": "UAH",
#                 "currency": "hrywna (Ukraina)",
#                 "mid": 0.0932
#             },
#             {
#                 "code": "JPY",
#                 "currency": "jen (Japonia)",
#                 "mid": 0.026805
#             },
#             {
#                 "code": "CZK",
#                 "currency": "korona czeska",
#                 "mid": 0.1699
#             },
#             {
#                 "code": "DKK",
#                 "currency": "korona du\u0144ska",
#                 "mid": 0.5735
#             },
#             {
#                 "code": "ISK",
#                 "currency": "korona islandzka",
#                 "mid": 0.028375
#             },
#             {
#                 "code": "NOK",
#                 "currency": "korona norweska",
#                 "mid": 0.3639
#             },
#             {
#                 "code": "SEK",
#                 "currency": "korona szwedzka",
#                 "mid": 0.3788
#             },
#             {
#                 "code": "RON",
#                 "currency": "lej rumu\u0144ski",
#                 "mid": 0.8594
#             },
#             {
#                 "code": "BGN",
#                 "currency": "lew (Bu\u0142garia)",
#                 "mid": 2.1863
#             },
#             {
#                 "code": "TRY",
#                 "currency": "lira turecka",
#                 "mid": 0.1122
#             },
#             {
#                 "code": "ILS",
#                 "currency": "nowy izraelski szekel",
#                 "mid": 1.0352
#             },
#             {
#                 "code": "CLP",
#                 "currency": "peso chilijskie",
#                 "mid": 0.004256
#             },
#             {
#                 "code": "PHP",
#                 "currency": "peso filipi\u0144skie",
#                 "mid": 0.0684
#             },
#             {
#                 "code": "MXN",
#                 "currency": "peso meksyka\u0144skie",
#                 "mid": 0.1964
#             },
#             {
#                 "code": "ZAR",
#                 "currency": "rand (Republika Po\u0142udniowej Afryki)",
#                 "mid": 0.2235
#             },
#             {
#                 "code": "BRL",
#                 "currency": "real (Brazylia)",
#                 "mid": 0.7056
#             },
#             {
#                 "code": "MYR",
#                 "currency": "ringgit (Malezja)",
#                 "mid": 0.9312
#             },
#             {
#                 "code": "IDR",
#                 "currency": "rupia indonezyjska",
#                 "mid": 0.00025368
#             },
#             {
#                 "code": "INR",
#                 "currency": "rupia indyjska",
#                 "mid": 0.045848
#             },
#             {
#                 "code": "KRW",
#                 "currency": "won po\u0142udniowokorea\u0144ski",
#                 "mid": 0.002922
#             },
#             {
#                 "code": "CNY",
#                 "currency": "yuan renminbi (Chiny)",
#                 "mid": 0.5471
#             },
#             {
#                 "code": "XDR",
#                 "currency": "SDR (MFW)",
#                 "mid": 5.1889
#             }
#         ],
#         "table": "A"
#     }
# ]
