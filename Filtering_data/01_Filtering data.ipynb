# %% [markdown]
# <H1><span style="color:lightblue">Filtering data</H1></span>
# While generating the <a>product_prices_renamed.csv</a> file the following processing errors occurred and they need to be found:<br><br>
# - In the **date** column, data from 1888 appeared - '1888-0',<br>
# - Check the **date** column for similar errors but with future values.<br>
# - In the **value** column, too high value was introduced – find it and locate the row where it is (use `query`),<br>
# - There was a spelling error in the **product_types** column for one of the products. Find it and the corresponding rows. How many such rows are there?<br>
#
# You do not need to assign the results to the variable: it is enough if you display them.
#
# > Based on the solution of this task, we will later correct all errors in the data.
#
# Hints:
#
# Subsection 2:
# 1. There is only one such value.
# 2. Use `loc` or `query` with the condition `date > '2020-1'`.
#
# Subsection 3:
# 1. There is only one such value.
# 1. Do the following:
# a) use `describe()`, to view percentiles,
# b) use `loc` or `query` to find erroneous entries,
#
# Subsection 4:
#
# You can do it in the following way:
# a) use `unique()` method to find all available values,
# b) use `loc` or `query` to find erroneous entries,
# c) The number of rows can be checked with the `shape` method.

# %%
import os

current_directory = './../01_Data'

files = os.listdir(current_directory)

print("Files and Directories:", files) # možnosť nájsť cestu
# Out:
# Files and Directories: ['province_product_price_stats.csv', '.DS_Store', 'no_errors.csv', 'product_prices_cleaned.csv', 'dims.xlsx', 'product_prices_renamed.csv', 'product_prices.xlsx', 'no_duplicates.csv', 'product_prices_cleaned.csv.zip', 'avg_monthly_prices.csv', 'product_prices.csv', 'price_volatility.csv', 'config.xlsx', 'raw']

# %%
data.query("Name == 'SUBCARPATHIA'") # všetko nájde v stĺpci hodnotu "SUBCARPATHIA" a načíta všetky hodnoty v riadkoch

data.loc[data["Name"] == "SUBCARPATHIA"] # najšetrnejší pre rýchlosť a pamäť

data[data["Name"] == "SUBCARPATHIA"] # isin miesto == a v hranatých zátvorkách list

# syntax == rovná, != nerovná , <=, >=, <, >      and & or | not ~ isin - je niečo v niečom s odpoveďou True/False

# %%
import pandas as pd
data = pd.read_csv(
                    '/Users/jeladobos/Documents/Learning/Data Analyst/5th session/Prework/01_Data/product_prices_renamed.csv', # path to the file with data (if we want to enter the name: filepath_or_buffer)
                    sep=';',  # column separator
                    decimal='.'  # sign separating the whole and fractional parts of a number
)

data.loc[data["date"] == "1888-0"]
# Out:
#                  province product_types currency  product_group_id  \
# 11908              LUBUSZ           NaN      PLN                 2
# 14765             SILESIA           NaN      PLN                 2
# 16125      WARMIA-MASURIA           NaN      PLN                 2
# 18737       LOWER SILESIA           NaN      PLN                 2
# 20293          HOLY CROSS           NaN      PLN                 2
# 33038               OPOLE           NaN      PLN                 2
# 50542       LESSER POLAND           NaN      PLN                 2
# 51536      GREATER POLAND           NaN      PLN                 2
# 85091           PODLASKIE           NaN      PLN                 2
# 95997           POMERANIA           NaN      PLN                 2
# 100513       SUBCARPATHIA           NaN      PLN                 2
# 110578             POLAND           NaN      PLN                 2
# 111306  KUYAVIA-POMERANIA           NaN      PLN                 2
# ...

# %%
import pandas as pd
data = pd.read_csv(
                    '/Users/jeladobos/Documents/Learning/Data Analyst/5th session/Prework/01_Data/product_prices_renamed.csv', # path to the file with data (if we want to enter the name: filepath_or_buffer)
                    sep=';',  # column separator
                    decimal='.'  # sign separating the whole and fractional parts of a number
)

data.query("date == '1888-0'")
# Out:
#                  province product_types currency  product_group_id  \
# 11908              LUBUSZ           NaN      PLN                 2
# 14765             SILESIA           NaN      PLN                 2
# 16125      WARMIA-MASURIA           NaN      PLN                 2
# 18737       LOWER SILESIA           NaN      PLN                 2
# 20293          HOLY CROSS           NaN      PLN                 2
# 33038               OPOLE           NaN      PLN                 2
# 50542       LESSER POLAND           NaN      PLN                 2
# 51536      GREATER POLAND           NaN      PLN                 2
# 85091           PODLASKIE           NaN      PLN                 2
# 95997           POMERANIA           NaN      PLN                 2
# 100513       SUBCARPATHIA           NaN      PLN                 2
# 110578             POLAND           NaN      PLN                 2
# 111306  KUYAVIA-POMERANIA           NaN      PLN                 2
# ...

# %%
import pandas as pd
data = pd.read_csv(
                    '/Users/jeladobos/Documents/Learning/Data Analyst/5th session/Prework/01_Data/product_prices_renamed.csv', # path to the file with data (if we want to enter the name: filepath_or_buffer)
                    sep=';',  # column separator
                    decimal='.'  # sign separating the whole and fractional parts of a number
)

data.loc[data["date"] > "2020-1"]
# Out:
#                  province product_types currency  product_group_id  \
# 1583           HOLY CROSS           NaN      PLN                 2
# 35525           PODLASKIE           NaN      PLN                 2
# 43258             SILESIA           NaN      PLN                 2
# 52595              LUBUSZ           NaN      PLN                 2
# 56032      GREATER POLAND           NaN      PLN                 2
# 72048               OPOLE           NaN      PLN                 2
# 73532                ŁÓDŹ           NaN      PLN                 2
# 84515              LUBLIN           NaN      PLN                 2
# 86619           POMERANIA           NaN      PLN                 2
# 98839      WEST POMERANIA           NaN      PLN                 2
# 102878            MASOVIA           NaN      PLN                 2
# 109773  KUYAVIA-POMERANIA           NaN      PLN                 2
# 127052      LESSER POLAND           NaN      PLN                 2
# ...

# %%
import pandas as pd
data = pd.read_csv(
                    '/Users/jeladobos/Documents/Learning/Data Analyst/5th session/Prework/01_Data/product_prices_renamed.csv', # path to the file with data (if we want to enter the name: filepath_or_buffer)
                    sep=';',  # column separator
                    decimal='.'  # sign separating the whole and fractional parts of a number
)

data.query("date > '2020-1'")
# Out:
#                  province product_types currency  product_group_id  \
# 1583           HOLY CROSS           NaN      PLN                 2
# 35525           PODLASKIE           NaN      PLN                 2
# 43258             SILESIA           NaN      PLN                 2
# 52595              LUBUSZ           NaN      PLN                 2
# 56032      GREATER POLAND           NaN      PLN                 2
# 72048               OPOLE           NaN      PLN                 2
# 73532                ŁÓDŹ           NaN      PLN                 2
# 84515              LUBLIN           NaN      PLN                 2
# 86619           POMERANIA           NaN      PLN                 2
# 98839      WEST POMERANIA           NaN      PLN                 2
# 102878            MASOVIA           NaN      PLN                 2
# 109773  KUYAVIA-POMERANIA           NaN      PLN                 2
# 127052      LESSER POLAND           NaN      PLN                 2
# ...

# %%
import pandas as pd
data = pd.read_csv(
                    '/Users/jeladobos/Documents/Learning/Data Analyst/5th session/Prework/01_Data/product_prices_renamed.csv', # path to the file with data (if we want to enter the name: filepath_or_buffer)
                    sep=';',  # column separator
                    decimal='.'  # sign separating the whole and fractional parts of a number
)
max_value = data["value"].max()

max_value_data = data.query("value == @max_value")

print(max_value_data)
# Out:
#                  province                     product_types currency  \
# 13724           POMERANIA  30% tomato concentrate - per 1kg      PLN
# 18768       LOWER SILESIA  30% tomato concentrate - per 1kg      PLN
# 22321      WEST POMERANIA  30% tomato concentrate - per 1kg      PLN
# 31268        SUBCARPATHIA  30% tomato concentrate - per 1kg      PLN
# 36958       LESSER POLAND  30% tomato concentrate - per 1kg      PLN
# 62346      GREATER POLAND  30% tomato concentrate - per 1kg      PLN
# 70851             MASOVIA  30% tomato concentrate - per 1kg      PLN
# 79924   KUYAVIA-POMERANIA  30% tomato concentrate - per 1kg      PLN
# 91306                ŁÓDŹ  30% tomato concentrate - per 1kg      PLN
# 96597               OPOLE  30% tomato concentrate - per 1kg      PLN
# 104235             POLAND  30% tomato concentrate - per 1kg      PLN
# 122007             LUBUSZ  30% tomato concentrate - per 1kg      PLN
# 130871         HOLY CROSS  30% tomato concentrate - per 1kg      PLN
# ...

# %%
import pandas as pd
data = pd.read_csv(
                    '/Users/jeladobos/Documents/Learning/Data Analyst/5th session/Prework/01_Data/product_prices_renamed.csv', # path to the file with data (if we want to enter the name: filepath_or_buffer)
                    sep=';',  # column separator
                    decimal='.'  # sign separating the whole and fractional parts of a number
)
max_value = data["value"].max()

max_value_data = data.loc[data["value"] == "max_value"]

print(max_value_data)
# Out:
# Empty DataFrame
# Columns: [province, product_types, currency, product_group_id, product_line, value, date]
# Index: []

# %%
import pandas as pd
data = pd.read_csv(
                    '/Users/jeladobos/Documents/Learning/Data Analyst/5th session/Prework/01_Data/product_prices_renamed.csv', # path to the file with data (if we want to enter the name: filepath_or_buffer)
                    sep=';',  # column separator
                    decimal='.'  # sign separating the whole and fractional parts of a number
)
# Use describe() to get summary statistics, including percentiles
description = data["value"].describe(percentiles=[1.0])

# Print the summary statistics including percentiles
print(description)

# Define a threshold for too high values
# For example, using the 90th percentile as a threshold
threshold = description["100%"]

# Find rows where 'value' is greater than the threshold
high_value_data = data.loc[data["value"] > threshold]

# Display the rows with high values
print("Rows with too high values:")
print(high_value_data)
# Out:
# count    137088.000000
# mean          6.615227
# std          34.112858
# min           0.000000
# 50%           3.090000
# 100%       3000.000000
# max        3000.000000
# Name: value, dtype: float64
# Rows with too high values:
# Empty DataFrame
# Columns: [province, product_types, currency, product_group_id, product_line, value, date]
# Index: []

# %%
import pandas as pd
data = pd.read_csv(
                    '/Users/jeladobos/Documents/Learning/Data Analyst/5th session/Prework/01_Data/product_prices_renamed.csv', # path to the file with data (if we want to enter the name: filepath_or_buffer)
                    sep=';',  # column separator
                    decimal='.'  # sign separating the whole and fractional parts of a number
)

data["product_types"].unique()
# Out:
# array([nan, 'whole pickled cucumbers 0.9l - per 1pc.',
#        'fresh chichen egges - per 666pcs.',
#        '30% tomato concentrate - per 1kg',
#        'frozen carrot and pea mix - per 1kg',
#        'beet sugar white, bagged - per 1kg',
#        'apple juice, boxed - per 1l', 'white table salt bagged - per 1kg',
#        'natural chocolate plain - per 1kg'], dtype=object)

# %%
import pandas as pd
data = pd.read_csv(
                    '/Users/jeladobos/Documents/Learning/Data Analyst/5th session/Prework/01_Data/product_prices_renamed.csv', # path to the file with data (if we want to enter the name: filepath_or_buffer)
                    sep=';',  # column separator
                    decimal='.'  # sign separating the whole and fractional parts of a number
)

data["product_types"].unique()
# Out:
# array([nan, 'whole pickled cucumbers 0.9l - per 1pc.',
#        'fresh chichen egges - per 666pcs.',
#        '30% tomato concentrate - per 1kg',
#        'frozen carrot and pea mix - per 1kg',
#        'beet sugar white, bagged - per 1kg',
#        'apple juice, boxed - per 1l', 'white table salt bagged - per 1kg',
#        'natural chocolate plain - per 1kg'], dtype=object)

# %%
import pandas as pd
data = pd.read_csv(
                    '/Users/jeladobos/Documents/Learning/Data Analyst/5th session/Prework/01_Data/product_prices_renamed.csv', # path to the file with data (if we want to enter the name: filepath_or_buffer)
                    sep=';',  # column separator
                    decimal='.'  # sign separating the whole and fractional parts of a number
)

data.query("product_types == 'fresh chichen egges - per 666pcs.'")
# Out:
#               province                      product_types currency  \
# 6       WEST POMERANIA  fresh chichen egges - per 666pcs.      PLN
# 13              POLAND  fresh chichen egges - per 666pcs.      PLN
# 38      WARMIA-MASURIA  fresh chichen egges - per 666pcs.      PLN
# 202     GREATER POLAND  fresh chichen egges - per 666pcs.      PLN
# 229     WARMIA-MASURIA  fresh chichen egges - per 666pcs.      PLN
# ...                ...                                ...      ...
# 149691       POMERANIA  fresh chichen egges - per 666pcs.      PLN
# 149718          LUBUSZ  fresh chichen egges - per 666pcs.      PLN
# 149724           OPOLE  fresh chichen egges - per 666pcs.      PLN
# 149767  WARMIA-MASURIA  fresh chichen egges - per 666pcs.      PLN
# 149838    SUBCARPATHIA  fresh chichen egges - per 666pcs.      PLN
#
#         product_group_id product_line  value     date
# 6                      3          NaN   0.00  2004-12
# ...

# %%
import pandas as pd
data = pd.read_csv(
                    '/Users/jeladobos/Documents/Learning/Data Analyst/5th session/Prework/01_Data/product_prices_renamed.csv', # path to the file with data (if we want to enter the name: filepath_or_buffer)
                    sep=';',  # column separator
                    decimal='.'  # sign separating the whole and fractional parts of a number
)

data.loc[data["product_types"] == "fresh chichen egges - per 666pcs."]
# Out:
#               province                      product_types currency  \
# 6       WEST POMERANIA  fresh chichen egges - per 666pcs.      PLN
# 13              POLAND  fresh chichen egges - per 666pcs.      PLN
# 38      WARMIA-MASURIA  fresh chichen egges - per 666pcs.      PLN
# 202     GREATER POLAND  fresh chichen egges - per 666pcs.      PLN
# 229     WARMIA-MASURIA  fresh chichen egges - per 666pcs.      PLN
# ...                ...                                ...      ...
# 149691       POMERANIA  fresh chichen egges - per 666pcs.      PLN
# 149718          LUBUSZ  fresh chichen egges - per 666pcs.      PLN
# 149724           OPOLE  fresh chichen egges - per 666pcs.      PLN
# 149767  WARMIA-MASURIA  fresh chichen egges - per 666pcs.      PLN
# 149838    SUBCARPATHIA  fresh chichen egges - per 666pcs.      PLN
#
#         product_group_id product_line  value     date
# 6                      3          NaN   0.00  2004-12
# ...

# %%
import pandas as pd
data = pd.read_csv(
                    '/Users/jeladobos/Documents/Learning/Data Analyst/5th session/Prework/01_Data/product_prices_renamed.csv', # path to the file with data (if we want to enter the name: filepath_or_buffer)
                    sep=';',  # column separator
                    decimal='.'  # sign separating the whole and fractional parts of a number
)

data.loc[data["product_types"] == "fresh chichen egges - per 666pcs.", "product_types"] = "fresh chicken eggs - per 666pcs."

data["product_types"].unique()
# Out:
# array([nan, 'whole pickled cucumbers 0.9l - per 1pc.',
#        'fresh chicken eggs - per 666pcs.',
#        '30% tomato concentrate - per 1kg',
#        'frozen carrot and pea mix - per 1kg',
#        'beet sugar white, bagged - per 1kg',
#        'apple juice, boxed - per 1l', 'white table salt bagged - per 1kg',
#        'natural chocolate plain - per 1kg'], dtype=object)
