# %% [markdown]
# <span style="color:orange; font-weight:bold;">***Extrakce dat přes BS***</span>
#
# --týmy se stále opakují podle sezony, takže je potřeba je vždy extrahovat pouze podle dané sezony.
# --takže začneme rokem 1990, pak 1991, pak 1992 atd. použiju podmínku <span style="color:orange; font-weight:bold;">if</span>

# %% [markdown]
# <big><big><big><span style="color:orange; font-weight:bold;">1990</span>

# %%
from bs4 import BeautifulSoup
import requests
import time

url = "https://www.scrapethissite.com/pages/forms/"

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/115.0.0.0 Safari/537.36'
}

response = requests.get(url, headers=headers)
time.sleep(1)  # Jedna sekunda, aby server nebyl přetížen

# Pokud je stránka dostupná
if response.status_code == 200:
    soup = BeautifulSoup(response.text, 'html.parser')

    # Vyhledání všech řádků s třídou "team" 
    teams = soup.find_all('tr', class_='team')
    
    # Pro každý tým extrahujeme data
    for team in teams:
        year = team.find('td', class_='year').text.strip()
        
        # filtrujeme pouze týmy z roku 1990
        if year == '1990':
            name = team.find('td', class_='name').text.strip()
            wins = team.find('td', class_='wins').text.strip()
            losses = team.find('td', class_='losses').text.strip()
            win_pct = team.find('td', class_='pct').text.strip()  # výherní procento
            goals_for = team.find('td', class_='gf').text.strip()  # goly vstřelené
            goals_against = team.find('td', class_='ga').text.strip()  # Góly obdržené
            diff = team.find('td', class_='diff').text.strip()  # Rozdíl skóre

            # Výpis dat pouze pro rok 1990
            print(f"Team: {name}, Year: {year}, Wins: {wins}, Losses: {losses}, Win %: {win_pct}, GF: {goals_for}, GA: {goals_against}, Diff: {diff}")
else:
    print("Chyba při načítání stránky:", response.status_code)
# Out:
# Team: Boston Bruins, Year: 1990, Wins: 44, Losses: 24, Win %: 0.55, GF: 299, GA: 264, Diff: 35
# Team: Buffalo Sabres, Year: 1990, Wins: 31, Losses: 30, Win %: 0.388, GF: 292, GA: 278, Diff: 14
# Team: Calgary Flames, Year: 1990, Wins: 46, Losses: 26, Win %: 0.575, GF: 344, GA: 263, Diff: 81
# Team: Chicago Blackhawks, Year: 1990, Wins: 49, Losses: 23, Win %: 0.613, GF: 284, GA: 211, Diff: 73
# Team: Detroit Red Wings, Year: 1990, Wins: 34, Losses: 38, Win %: 0.425, GF: 273, GA: 298, Diff: -25
# Team: Edmonton Oilers, Year: 1990, Wins: 37, Losses: 37, Win %: 0.463, GF: 272, GA: 272, Diff: 0
# Team: Hartford Whalers, Year: 1990, Wins: 31, Losses: 38, Win %: 0.388, GF: 238, GA: 276, Diff: -38
# Team: Los Angeles Kings, Year: 1990, Wins: 46, Losses: 24, Win %: 0.575, GF: 340, GA: 254, Diff: 86
# Team: Minnesota North Stars, Year: 1990, Wins: 27, Losses: 39, Win %: 0.338, GF: 256, GA: 266, Diff: -10
# ...

# %% [markdown]
# **Převedení do framu přes <span style="color:orange; font-weight:bold;">PANDAS</span>** rozdělení podle sezony:

# %% [markdown]
# ***všechny týmy*** pro rok <big><big><big><big><span style="color:orange; font-weight:bold;">1990</span>

# %%
import pandas as pd

data = [
    {"Team": "Boston Bruins", "Year": 1990, "Wins": 44, "Losses": 24, "OT Losses": "", "Win %": 0.55, "GF": 299, "GA": 264, "Diff": 35},
    {"Team": "Buffalo Sabres", "Year": 1990, "Wins": 31, "Losses": 30, "OT Losses": "", "Win %": 0.388, "GF": 292, "GA": 278, "Diff": 14},
    {"Team": "Calgary Flames", "Year": 1990, "Wins": 46, "Losses": 26, "OT Losses": "", "Win %": 0.575, "GF": 344, "GA": 263, "Diff": 81},
    {"Team": "Chicago Blackhawks", "Year": 1990, "Wins": 49, "Losses": 23, "OT Losses": "", "Win %": 0.613, "GF": 284, "GA": 211, "Diff": 73},
    {"Team": "Detroit Red Wings", "Year": 1990, "Wins": 34, "Losses": 38, "OT Losses": "", "Win %": 0.425, "GF": 273, "GA": 298, "Diff": -25},
    {"Team": "Edmonton Oilers", "Year": 1990, "Wins": 37, "Losses": 37, "OT Losses": "", "Win %": 0.463, "GF": 272, "GA": 272, "Diff": 0},
    {"Team": "Hartford Whalers", "Year": 1990, "Wins": 31, "Losses": 38, "OT Losses": "", "Win %": 0.388, "GF": 238, "GA": 276, "Diff": -38},
    {"Team": "Los Angeles Kings", "Year": 1990, "Wins": 46, "Losses": 24, "OT Losses": "", "Win %": 0.575, "GF": 340, "GA": 254, "Diff": 86},
    {"Team": "Minnesota North Stars", "Year": 1990, "Wins": 27, "Losses": 39, "OT Losses": "", "Win %": 0.338, "GF": 256, "GA": 266, "Diff": -10},
    {"Team": "Montreal Canadiens", "Year": 1990, "Wins": 39, "Losses": 30, "OT Losses": "", "Win %": 0.487, "GF": 273, "GA": 249, "Diff": 24},
    {"Team": "New Jersey Devils", "Year": 1990, "Wins": 32, "Losses": 33, "OT Losses": "", "Win %": 0.4, "GF": 272, "GA": 264, "Diff": 8},
    {"Team": "New York Islanders", "Year": 1990, "Wins": 25, "Losses": 45, "OT Losses": "", "Win %": 0.312, "GF": 223, "GA": 290, "Diff": -67},
    {"Team": "New York Rangers", "Year": 1990, "Wins": 36, "Losses": 31, "OT Losses": "", "Win %": 0.45, "GF": 297, "GA": 265, "Diff": 32},
    {"Team": "Philadelphia Flyers", "Year": 1990, "Wins": 33, "Losses": 37, "OT Losses": "", "Win %": 0.412, "GF": 252, "GA": 267, "Diff": -15},
    {"Team": "Pittsburgh Penguins", "Year": 1990, "Wins": 41, "Losses": 33, "OT Losses": "", "Win %": 0.512, "GF": 342, "GA": 305, "Diff": 37},
    {"Team": "Quebec Nordiques", "Year": 1990, "Wins": 16, "Losses": 50, "OT Losses": "", "Win %": 0.2, "GF": 236, "GA": 354, "Diff": -118},
    {"Team": "St. Louis Blues", "Year": 1990, "Wins": 47, "Losses": 22, "OT Losses": "", "Win %": 0.588, "GF": 310, "GA": 250, "Diff": 60},
    {"Team": "Toronto Maple Leafs", "Year": 1990, "Wins": 23, "Losses": 46, "OT Losses": "", "Win %": 0.287, "GF": 241, "GA": 318, "Diff": -77},
    {"Team": "Vancouver Canucks", "Year": 1990, "Wins": 28, "Losses": 43, "OT Losses": "", "Win %": 0.35, "GF": 243, "GA": 315, "Diff": -72},
    {"Team": "Washington Capitals", "Year": 1990, "Wins": 37, "Losses": 36, "OT Losses": "", "Win %": 0.463, "GF": 258, "GA": 258, "Diff": 0},
    {"Team": "Winnipeg Jets", "Year": 1990, "Wins": 26, "Losses": 43, "OT Losses": "", "Win %": 0.325, "GF": 260, "GA": 288, "Diff": -28},
]

# Cvytvoření dataframu
df = pd.DataFrame(data)

# zobrazení všech řádku
pd.set_option('display.max_rows', None)

print(df)
# Out:
#                      Team  Year  Wins  Losses OT Losses  Win %   GF   GA  Diff
# 0           Boston Bruins  1990    44      24            0.550  299  264    35
# 1          Buffalo Sabres  1990    31      30            0.388  292  278    14
# 2          Calgary Flames  1990    46      26            0.575  344  263    81
# 3      Chicago Blackhawks  1990    49      23            0.613  284  211    73
# 4       Detroit Red Wings  1990    34      38            0.425  273  298   -25
# 5         Edmonton Oilers  1990    37      37            0.463  272  272     0
# 6        Hartford Whalers  1990    31      38            0.388  238  276   -38
# 7       Los Angeles Kings  1990    46      24            0.575  340  254    86
# 8   Minnesota North Stars  1990    27      39            0.338  256  266   -10
# 9      Montreal Canadiens  1990    39      30            0.487  273  249    24
# 10      New Jersey Devils  1990    32      33            0.400  272  264     8
# ...

# %% [markdown]
# <big><big><big><span style="color:orange; font-weight:bold;">1991</span>

# %%
from bs4 import BeautifulSoup
import requests
import time

url = "https://www.scrapethissite.com/pages/forms/?per_page=100"

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/115.0.0.0 Safari/537.36'
}

response = requests.get(url, headers=headers)
time.sleep(1)  # Jedna sekunda, aby server nebyl přetížen

# Pokud je stránka dostupná
if response.status_code == 200:
    soup = BeautifulSoup(response.text, 'html.parser')

    # Vyhledání všech řádků s třídou "team" 
    teams = soup.find_all('tr', class_='team')
    
    # Pro každý tým extrahujeme data
    for team in teams:
        year = team.find('td', class_='year').text.strip()
        
        # filtrujeme pouze týmy z roku 1990
        if year == '1991':
            name = team.find('td', class_='name').text.strip()
            wins = team.find('td', class_='wins').text.strip()
            losses = team.find('td', class_='losses').text.strip()
            win_pct = team.find('td', class_='pct').text.strip()  # výherní procento
            goals_for = team.find('td', class_='gf').text.strip()  # goly vstřelené
            goals_against = team.find('td', class_='ga').text.strip()  # Góly obdržené
            diff = team.find('td', class_='diff').text.strip()  # Rozdíl skóre

            # Výpis dat pouze pro rok 1990
            print(f"Team: {name}, Year: {year}, Wins: {wins}, Losses: {losses}, Win %: {win_pct}, GF: {goals_for}, GA: {goals_against}, Diff: {diff}")
else:
    print("Chyba při načítání stránky:", response.status_code)
# Out:
# Team: Boston Bruins, Year: 1991, Wins: 36, Losses: 32, Win %: 0.45, GF: 270, GA: 275, Diff: -5
# Team: Buffalo Sabres, Year: 1991, Wins: 31, Losses: 37, Win %: 0.388, GF: 289, GA: 299, Diff: -10
# Team: Calgary Flames, Year: 1991, Wins: 31, Losses: 37, Win %: 0.388, GF: 296, GA: 305, Diff: -9
# Team: Chicago Blackhawks, Year: 1991, Wins: 36, Losses: 29, Win %: 0.45, GF: 257, GA: 236, Diff: 21
# Team: Detroit Red Wings, Year: 1991, Wins: 43, Losses: 25, Win %: 0.537, GF: 320, GA: 256, Diff: 64
# Team: Edmonton Oilers, Year: 1991, Wins: 36, Losses: 34, Win %: 0.45, GF: 295, GA: 297, Diff: -2
# Team: Hartford Whalers, Year: 1991, Wins: 26, Losses: 41, Win %: 0.325, GF: 247, GA: 283, Diff: -36
# Team: Los Angeles Kings, Year: 1991, Wins: 35, Losses: 31, Win %: 0.438, GF: 287, GA: 296, Diff: -9
# Team: Minnesota North Stars, Year: 1991, Wins: 32, Losses: 42, Win %: 0.4, GF: 246, GA: 278, Diff: -32
# ...

# %%
import pandas as pd

# 1991
data = [
    {"Team": "Boston Bruins", "Year": 1991, "Wins": 36, "Losses": 32, "Win %": 0.45, "GF": 270, "GA": 275, "Diff": -5},
    {"Team": "Buffalo Sabres", "Year": 1991, "Wins": 31, "Losses": 37, "Win %": 0.388, "GF": 289, "GA": 299, "Diff": -10},
    {"Team": "Calgary Flames", "Year": 1991, "Wins": 31, "Losses": 37, "Win %": 0.388, "GF": 296, "GA": 305, "Diff": -9},
    {"Team": "Chicago Blackhawks", "Year": 1991, "Wins": 36, "Losses": 29, "Win %": 0.45, "GF": 257, "GA": 236, "Diff": 21},
    {"Team": "Detroit Red Wings", "Year": 1991, "Wins": 43, "Losses": 25, "Win %": 0.537, "GF": 320, "GA": 256, "Diff": 64},
    {"Team": "Edmonton Oilers", "Year": 1991, "Wins": 36, "Losses": 34, "Win %": 0.45, "GF": 295, "GA": 297, "Diff": -2},
    {"Team": "Hartford Whalers", "Year": 1991, "Wins": 26, "Losses": 41, "Win %": 0.325, "GF": 247, "GA": 283, "Diff": -36},
    {"Team": "Los Angeles Kings", "Year": 1991, "Wins": 35, "Losses": 31, "Win %": 0.438, "GF": 287, "GA": 296, "Diff": -9},
    {"Team": "Minnesota North Stars", "Year": 1991, "Wins": 32, "Losses": 42, "Win %": 0.4, "GF": 246, "GA": 278, "Diff": -32},
    {"Team": "Montreal Canadiens", "Year": 1991, "Wins": 41, "Losses": 28, "Win %": 0.512, "GF": 267, "GA": 207, "Diff": 60},
    {"Team": "New Jersey Devils", "Year": 1991, "Wins": 38, "Losses": 31, "Win %": 0.475, "GF": 289, "GA": 259, "Diff": 30},
    {"Team": "New York Islanders", "Year": 1991, "Wins": 34, "Losses": 35, "Win %": 0.425, "GF": 291, "GA": 299, "Diff": -8},
    {"Team": "New York Rangers", "Year": 1991, "Wins": 50, "Losses": 25, "Win %": 0.625, "GF": 321, "GA": 246, "Diff": 75},
    {"Team": "Philadelphia Flyers", "Year": 1991, "Wins": 32, "Losses": 37, "Win %": 0.4, "GF": 252, "GA": 273, "Diff": -21},
    {"Team": "Pittsburgh Penguins", "Year": 1991, "Wins": 39, "Losses": 32, "Win %": 0.487, "GF": 343, "GA": 308, "Diff": 35},
    {"Team": "Quebec Nordiques", "Year": 1991, "Wins": 20, "Losses": 48, "Win %": 0.25, "GF": 255, "GA": 318, "Diff": -63},
    {"Team": "San Jose Sharks", "Year": 1991, "Wins": 17, "Losses": 58, "Win %": 0.212, "GF": 219, "GA": 359, "Diff": -140},
    {"Team": "St. Louis Blues", "Year": 1991, "Wins": 36, "Losses": 33, "Win %": 0.45, "GF": 279, "GA": 266, "Diff": 13},
    {"Team": "Toronto Maple Leafs", "Year": 1991, "Wins": 30, "Losses": 43, "Win %": 0.375, "GF": 234, "GA": 294, "Diff": -60},
    {"Team": "Vancouver Canucks", "Year": 1991, "Wins": 42, "Losses": 26, "Win %": 0.525, "GF": 285, "GA": 250, "Diff": 35},
    {"Team": "Washington Capitals", "Year": 1991, "Wins": 45, "Losses": 27, "Win %": 0.562, "GF": 330, "GA": 275, "Diff": 55},
    {"Team": "Winnipeg Jets", "Year": 1991, "Wins": 33, "Losses": 32, "Win %": 0.412, "GF": 251, "GA": 244, "Diff": 7},
]

df = pd.DataFrame(data)
pd.set_option('display.max_rows', None)
print(df)
# Out:
#                      Team  Year  Wins  Losses  Win %   GF   GA  Diff
# 0           Boston Bruins  1991    36      32  0.450  270  275    -5
# 1          Buffalo Sabres  1991    31      37  0.388  289  299   -10
# 2          Calgary Flames  1991    31      37  0.388  296  305    -9
# 3      Chicago Blackhawks  1991    36      29  0.450  257  236    21
# 4       Detroit Red Wings  1991    43      25  0.537  320  256    64
# 5         Edmonton Oilers  1991    36      34  0.450  295  297    -2
# 6        Hartford Whalers  1991    26      41  0.325  247  283   -36
# 7       Los Angeles Kings  1991    35      31  0.438  287  296    -9
# 8   Minnesota North Stars  1991    32      42  0.400  246  278   -32
# 9      Montreal Canadiens  1991    41      28  0.512  267  207    60
# 10      New Jersey Devils  1991    38      31  0.475  289  259    30
# 11     New York Islanders  1991    34      35  0.425  291  299    -8
# 12       New York Rangers  1991    50      25  0.625  321  246    75
# ...

# %% [markdown]
# <big><big><big><span style="color:orange; font-weight:bold;">1992</span>

# %%
from bs4 import BeautifulSoup
import requests
import time

url = "https://www.scrapethissite.com/pages/forms/?per_page=100"

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/115.0.0.0 Safari/537.36'
}

response = requests.get(url, headers=headers)
time.sleep(1)  # Jedna sekunda, aby server nebyl přetížen

# Pokud je stránka dostupná
if response.status_code == 200:
    soup = BeautifulSoup(response.text, 'html.parser')

    # Vyhledání všech řádků s třídou "team" 
    teams = soup.find_all('tr', class_='team')
    
    # Pro každý tým extrahujeme data
    for team in teams:
        year = team.find('td', class_='year').text.strip()
        
        # filtrujeme pouze týmy z roku 1990
        if year == '1992':
            name = team.find('td', class_='name').text.strip()
            wins = team.find('td', class_='wins').text.strip()
            losses = team.find('td', class_='losses').text.strip()
            win_pct = team.find('td', class_='pct').text.strip()  # výherní procento
            goals_for = team.find('td', class_='gf').text.strip()  # goly vstřelené
            goals_against = team.find('td', class_='ga').text.strip()  # Góly obdržené
            diff = team.find('td', class_='diff').text.strip()  # Rozdíl skóre

            # Výpis dat pouze pro rok 1990
            print(f"Team: {name}, Year: {year}, Wins: {wins}, Losses: {losses}, OT Losses: {ot_losses}, Win %: {win_pct}, GF: {goals_for}, GA: {goals_against}, Diff: {diff}")
else:
    print("Chyba při načítání stránky:", response.status_code)
# Out:
# Team: Boston Bruins, Year: 1992, Wins: 51, Losses: 26, OT Losses: 0, Win %: 0.607, GF: 332, GA: 268, Diff: 64
# Team: Buffalo Sabres, Year: 1992, Wins: 38, Losses: 36, OT Losses: 0, Win %: 0.452, GF: 335, GA: 297, Diff: 38
# Team: Calgary Flames, Year: 1992, Wins: 43, Losses: 30, OT Losses: 0, Win %: 0.512, GF: 322, GA: 282, Diff: 40
# Team: Chicago Blackhawks, Year: 1992, Wins: 47, Losses: 25, OT Losses: 0, Win %: 0.56, GF: 279, GA: 230, Diff: 49
# Team: Detroit Red Wings, Year: 1992, Wins: 47, Losses: 28, OT Losses: 0, Win %: 0.56, GF: 369, GA: 280, Diff: 89
# Team: Edmonton Oilers, Year: 1992, Wins: 26, Losses: 50, OT Losses: 0, Win %: 0.31, GF: 242, GA: 337, Diff: -95
# Team: Hartford Whalers, Year: 1992, Wins: 26, Losses: 52, OT Losses: 0, Win %: 0.31, GF: 284, GA: 369, Diff: -85
# Team: Los Angeles Kings, Year: 1992, Wins: 39, Losses: 35, OT Losses: 0, Win %: 0.464, GF: 338, GA: 340, Diff: -2
# ...

# %%
import pandas as pd

# 1992
data = [
    {"Team": "Boston Bruins", "Year": 1992, "Wins": 51, "Losses": 26, "Win %": 0.607, "GF": 332, "GA": 268, "Diff": 64},
    {"Team": "Buffalo Sabres", "Year": 1992, "Wins": 38, "Losses": 36, "Win %": 0.452, "GF": 335, "GA": 297, "Diff": 38},
    {"Team": "Calgary Flames", "Year": 1992, "Wins": 43, "Losses": 30, "Win %": 0.512, "GF": 322, "GA": 282, "Diff": 40},
    {"Team": "Chicago Blackhawks", "Year": 1992, "Wins": 47, "Losses": 25, "Win %": 0.56, "GF": 279, "GA": 230, "Diff": 49},
    {"Team": "Detroit Red Wings", "Year": 1992, "Wins": 47, "Losses": 28, "Win %": 0.56, "GF": 369, "GA": 280, "Diff": 89},
    {"Team": "Edmonton Oilers", "Year": 1992, "Wins": 26, "Losses": 50, "Win %": 0.31, "GF": 242, "GA": 337, "Diff": -95},
    {"Team": "Hartford Whalers", "Year": 1992, "Wins": 26, "Losses": 52, "Win %": 0.31, "GF": 284, "GA": 369, "Diff": -85},
    {"Team": "Los Angeles Kings", "Year": 1992, "Wins": 39, "Losses": 35, "Win %": 0.464, "GF": 338, "GA": 340, "Diff": -2},
    {"Team": "Minnesota North Stars", "Year": 1992, "Wins": 36, "Losses": 38, "Win %": 0.429, "GF": 272, "GA": 293, "Diff": -21},
    {"Team": "Montreal Canadiens", "Year": 1992, "Wins": 48, "Losses": 30, "Win %": 0.571, "GF": 326, "GA": 280, "Diff": 46},
    {"Team": "New Jersey Devils", "Year": 1992, "Wins": 40, "Losses": 37, "Win %": 0.476, "GF": 308, "GA": 299, "Diff": 9},
    {"Team": "New York Islanders", "Year": 1992, "Wins": 40, "Losses": 37, "Win %": 0.476, "GF": 335, "GA": 297, "Diff": 38},
    {"Team": "New York Rangers", "Year": 1992, "Wins": 34, "Losses": 39, "Win %": 0.405, "GF": 304, "GA": 308, "Diff": -4},
    {"Team": "Ottawa Senators", "Year": 1992, "Wins": 10, "Losses": 70, "Win %": 0.119, "GF": 202, "GA": 395, "Diff": -193},
    {"Team": "Philadelphia Flyers", "Year": 1992, "Wins": 36, "Losses": 37, "Win %": 0.429, "GF": 319, "GA": 319, "Diff": 0},
    {"Team": "Pittsburgh Penguins", "Year": 1992, "Wins": 56, "Losses": 21, "Win %": 0.667, "GF": 367, "GA": 268, "Diff": 99},
    {"Team": "Quebec Nordiques", "Year": 1992, "Wins": 47, "Losses": 27, "Win %": 0.56, "GF": 351, "GA": 300, "Diff": 51},
    {"Team": "San Jose Sharks", "Year": 1992, "Wins": 11, "Losses": 71, "Win %": 0.131, "GF": 218, "GA": 414, "Diff": -196},
    {"Team": "St. Louis Blues", "Year": 1992, "Wins": 37, "Losses": 36, "Win %": 0.44, "GF": 282, "GA": 278, "Diff": 4},
    {"Team": "Tampa Bay Lightning", "Year": 1992, "Wins": 23, "Losses": 54, "Win %": 0.274, "GF": 245, "GA": 332, "Diff": -87},
    {"Team": "Toronto Maple Leafs", "Year": 1992, "Wins": 44, "Losses": 29, "Win %": 0.524, "GF": 288, "GA": 241, "Diff": 47},
    {"Team": "Vancouver Canucks", "Year": 1992, "Wins": 46, "Losses": 29, "Win %": 0.548, "GF": 346, "GA": 278, "Diff": 68},
    {"Team": "Washington Capitals", "Year": 1992, "Wins": 43, "Losses": 34, "Win %": 0.512, "GF": 325, "GA": 286, "Diff": 39},
    {"Team": "Winnipeg Jets", "Year": 1992, "Wins": 40, "Losses": 37, "Win %": 0.476, "GF": 322, "GA": 320, "Diff": 2},
]

df = pd.DataFrame(data)
pd.set_option('display.max_rows', None)
print(df)
# Out:
#                      Team  Year  Wins  Losses  Win %   GF   GA  Diff
# 0           Boston Bruins  1992    51      26  0.607  332  268    64
# 1          Buffalo Sabres  1992    38      36  0.452  335  297    38
# 2          Calgary Flames  1992    43      30  0.512  322  282    40
# 3      Chicago Blackhawks  1992    47      25  0.560  279  230    49
# 4       Detroit Red Wings  1992    47      28  0.560  369  280    89
# 5         Edmonton Oilers  1992    26      50  0.310  242  337   -95
# 6        Hartford Whalers  1992    26      52  0.310  284  369   -85
# 7       Los Angeles Kings  1992    39      35  0.464  338  340    -2
# 8   Minnesota North Stars  1992    36      38  0.429  272  293   -21
# 9      Montreal Canadiens  1992    48      30  0.571  326  280    46
# 10      New Jersey Devils  1992    40      37  0.476  308  299     9
# 11     New York Islanders  1992    40      37  0.476  335  297    38
# 12       New York Rangers  1992    34      39  0.405  304  308    -4
# ...

# %% [markdown]
# <big><big><big><span style="color:orange; font-weight:bold;">1993</span>

# %%
from bs4 import BeautifulSoup
import requests
import time

url = "https://www.scrapethissite.com/pages/forms/?per_page=100"

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/115.0.0.0 Safari/537.36'
}

response = requests.get(url, headers=headers)
time.sleep(1)  # Jedna sekunda, aby server nebyl přetížen

# Pokud je stránka dostupná
if response.status_code == 200:
    soup = BeautifulSoup(response.text, 'html.parser')

    # Vyhledání všech řádků s třídou "team" 
    teams = soup.find_all('tr', class_='team')
    
    # Pro každý tým extrahujeme data
    for team in teams:
        year = team.find('td', class_='year').text.strip()
        
        # filtrujeme pouze týmy z roku 1990
        if year == '1993':
            name = team.find('td', class_='name').text.strip()
            wins = team.find('td', class_='wins').text.strip()
            losses = team.find('td', class_='losses').text.strip()
            goals_for = team.find('td', class_='gf').text.strip()  # goly vstřelené
            goals_against = team.find('td', class_='ga').text.strip()  # Góly obdržené
            diff = team.find('td', class_='diff').text.strip()  # Rozdíl skóre

            # Výpis dat pouze pro rok 1990
            print(f"Team: {name}, Year: {year}, Wins: {wins}, Losses: {losses}, OT Losses: {ot_losses}, Win %: {win_pct}, GF: {goals_for}, GA: {goals_against}, Diff: {diff}")
else:
    print("Chyba při načítání stránky:", response.status_code)
# Out:
# Team: Mighty Ducks of Anaheim, Year: 1993, Wins: 33, Losses: 46, OT Losses: 0, Win %: 0.393, GF: 229, GA: 251, Diff: -22
# Team: Boston Bruins, Year: 1993, Wins: 42, Losses: 29, OT Losses: 0, Win %: 0.5, GF: 289, GA: 252, Diff: 37
# Team: Buffalo Sabres, Year: 1993, Wins: 43, Losses: 32, OT Losses: 0, Win %: 0.512, GF: 282, GA: 218, Diff: 64
# Team: Calgary Flames, Year: 1993, Wins: 42, Losses: 29, OT Losses: 0, Win %: 0.5, GF: 302, GA: 256, Diff: 46
# Team: Chicago Blackhawks, Year: 1993, Wins: 39, Losses: 36, OT Losses: 0, Win %: 0.464, GF: 254, GA: 240, Diff: 14
# Team: Dallas Stars, Year: 1993, Wins: 42, Losses: 29, OT Losses: 0, Win %: 0.5, GF: 286, GA: 265, Diff: 21
# Team: Detroit Red Wings, Year: 1993, Wins: 46, Losses: 30, OT Losses: 0, Win %: 0.548, GF: 356, GA: 275, Diff: 81
# Team: Edmonton Oilers, Year: 1993, Wins: 25, Losses: 45, OT Losses: 0, Win %: 0.298, GF: 261, GA: 305, Diff: -44
# ...

# %%
import pandas as pd

data = [
    {"Team": "Mighty Ducks of Anaheim", "Year": 1993, "Wins": 33, "Losses": 46, "Win %": 0.393, "GF": 229, "GA": 251, "Diff": -22},
    {"Team": "Boston Bruins", "Year": 1993, "Wins": 42, "Losses": 29, "Win %": 0.5, "GF": 289, "GA": 252, "Diff": 37},
    {"Team": "Buffalo Sabres", "Year": 1993, "Wins": 43, "Losses": 32, "Win %": 0.512, "GF": 282, "GA": 218, "Diff": 64},
    {"Team": "Calgary Flames", "Year": 1993, "Wins": 42, "Losses": 29, "Win %": 0.5, "GF": 302, "GA": 256, "Diff": 46},
    {"Team": "Chicago Blackhawks", "Year": 1993, "Wins": 39, "Losses": 36, "Win %": 0.464, "GF": 254, "GA": 240, "Diff": 14},
    {"Team": "Dallas Stars", "Year": 1993, "Wins": 42, "Losses": 29, "Win %": 0.5, "GF": 286, "GA": 265, "Diff": 21},
    {"Team": "Detroit Red Wings", "Year": 1993, "Wins": 46, "Losses": 30, "Win %": 0.548, "GF": 356, "GA": 275, "Diff": 81},
    {"Team": "Edmonton Oilers", "Year": 1993, "Wins": 25, "Losses": 45, "Win %": 0.298, "GF": 261, "GA": 305, "Diff": -44},
    {"Team": "Florida Panthers", "Year": 1993, "Wins": 33, "Losses": 34, "Win %": 0.393, "GF": 233, "GA": 233, "Diff": 0},
    {"Team": "Hartford Whalers", "Year": 1993, "Wins": 27, "Losses": 48, "Win %": 0.321, "GF": 227, "GA": 288, "Diff": -61},
    {"Team": "Los Angeles Kings", "Year": 1993, "Wins": 27, "Losses": 45, "Win %": 0.321, "GF": 294, "GA": 322, "Diff": -28},
    {"Team": "Montreal Canadiens", "Year": 1993, "Wins": 41, "Losses": 29, "Win %": 0.488, "GF": 283, "GA": 248, "Diff": 35},
    {"Team": "New Jersey Devils", "Year": 1993, "Wins": 47, "Losses": 25, "Win %": 0.56, "GF": 306, "GA": 220, "Diff": 86},
    {"Team": "New York Islanders", "Year": 1993, "Wins": 36, "Losses": 36, "Win %": 0.429, "GF": 282, "GA": 264, "Diff": 18},
    {"Team": "New York Rangers", "Year": 1993, "Wins": 52, "Losses": 24, "Win %": 0.619, "GF": 299, "GA": 231, "Diff": 68},
    {"Team": "Ottawa Senators", "Year": 1993, "Wins": 14, "Losses": 61, "Win %": 0.167, "GF": 201, "GA": 397, "Diff": -196},
    {"Team": "Philadelphia Flyers", "Year": 1993, "Wins": 35, "Losses": 39, "Win %": 0.417, "GF": 294, "GA": 314, "Diff": -20},
    {"Team": "Pittsburgh Penguins", "Year": 1993, "Wins": 44, "Losses": 27, "Win %": 0.524, "GF": 299, "GA": 285, "Diff": 14},
    {"Team": "Quebec Nordiques", "Year": 1993, "Wins": 34, "Losses": 42, "Win %": 0.405, "GF": 277, "GA": 292, "Diff": -15},
    {"Team": "San Jose Sharks", "Year": 1993, "Wins": 33, "Losses": 35, "Win %": 0.393, "GF": 252, "GA": 265, "Diff": -13},
    {"Team": "St. Louis Blues", "Year": 1993, "Wins": 40, "Losses": 33, "Win %": 0.476, "GF": 270, "GA": 283, "Diff": -13},
    {"Team": "Tampa Bay Lightning", "Year": 1993, "Wins": 30, "Losses": 43, "Win %": 0.357, "GF": 224, "GA": 251, "Diff": -27},
    {"Team": "Toronto Maple Leafs", "Year": 1993, "Wins": 43, "Losses": 29, "Win %": 0.512, "GF": 280, "GA": 243, "Diff": 37},
    {"Team": "Vancouver Canucks", "Year": 1993, "Wins": 41, "Losses": 40, "Win %": 0.488, "GF": 279, "GA": 276, "Diff": 3},
    {"Team": "Washington Capitals", "Year": 1993, "Wins": 39, "Losses": 35, "Win %": 0.464, "GF": 277, "GA": 263, "Diff": 14},
    {"Team": "Winnipeg Jets", "Year": 1993, "Wins": 24, "Losses": 51, "Win %": 0.286, "GF": 245, "GA": 344, "Diff": -99},
]

df = pd.DataFrame(data)
pd.set_option('display.max_rows', None)
print(df)
# Out:
#                        Team  Year  Wins  Losses  Win %   GF   GA  Diff
# 0   Mighty Ducks of Anaheim  1993    33      46  0.393  229  251   -22
# 1             Boston Bruins  1993    42      29  0.500  289  252    37
# 2            Buffalo Sabres  1993    43      32  0.512  282  218    64
# 3            Calgary Flames  1993    42      29  0.500  302  256    46
# 4        Chicago Blackhawks  1993    39      36  0.464  254  240    14
# 5              Dallas Stars  1993    42      29  0.500  286  265    21
# 6         Detroit Red Wings  1993    46      30  0.548  356  275    81
# 7           Edmonton Oilers  1993    25      45  0.298  261  305   -44
# 8          Florida Panthers  1993    33      34  0.393  233  233     0
# 9          Hartford Whalers  1993    27      48  0.321  227  288   -61
# 10        Los Angeles Kings  1993    27      45  0.321  294  322   -28
# 11       Montreal Canadiens  1993    41      29  0.488  283  248    35
# ...

# %% [markdown]
# <big><big><big><span style="color:orange; font-weight:bold;">1994</span>

# %%
from bs4 import BeautifulSoup
import requests
import time

url = "https://www.scrapethissite.com/pages/forms/?page_num=1&per_page=400"

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/115.0.0.0 Safari/537.36'
}

response = requests.get(url, headers=headers)
time.sleep(1)  # Jedna sekunda, aby server nebyl přetížen

# Pokud je stránka dostupná
if response.status_code == 200:
    soup = BeautifulSoup(response.text, 'html.parser')

    # Vyhledání všech řádků s třídou "team" 
    teams = soup.find_all('tr', class_='team')
    
    # Pro každý tým extrahujeme data
    for team in teams:
        year = team.find('td', class_='year').text.strip()
        
        # filtrujeme pouze týmy z roku 1990
        if year == '1994':
            name = team.find('td', class_='name').text.strip()
            wins = team.find('td', class_='wins').text.strip()
            losses = team.find('td', class_='losses').text.strip()
            goals_for = team.find('td', class_='gf').text.strip()  # goly vstřelené
            goals_against = team.find('td', class_='ga').text.strip()  # Góly obdržené
            diff = team.find('td', class_='diff').text.strip()  # Rozdíl skóre

            # Výpis dat pouze pro rok 1990
            print(f"Team: {name}, Year: {year}, Wins: {wins}, Losses: {losses}, OT Losses: {ot_losses}, Win %: {win_pct}, GF: {goals_for}, GA: {goals_against}, Diff: {diff}")
else:
    print("Chyba při načítání stránky:", response.status_code)
# Out:
# Team: Mighty Ducks of Anaheim, Year: 1994, Wins: 16, Losses: 27, OT Losses: 0, Win %: 0.476, GF: 125, GA: 164, Diff: -39
# Team: Boston Bruins, Year: 1994, Wins: 27, Losses: 18, OT Losses: 0, Win %: 0.476, GF: 150, GA: 127, Diff: 23
# Team: Buffalo Sabres, Year: 1994, Wins: 22, Losses: 19, OT Losses: 0, Win %: 0.476, GF: 130, GA: 119, Diff: 11
# Team: Calgary Flames, Year: 1994, Wins: 24, Losses: 17, OT Losses: 0, Win %: 0.476, GF: 163, GA: 135, Diff: 28
# Team: Chicago Blackhawks, Year: 1994, Wins: 24, Losses: 19, OT Losses: 0, Win %: 0.476, GF: 156, GA: 115, Diff: 41
# Team: Dallas Stars, Year: 1994, Wins: 17, Losses: 23, OT Losses: 0, Win %: 0.476, GF: 136, GA: 135, Diff: 1
# Team: Detroit Red Wings, Year: 1994, Wins: 33, Losses: 11, OT Losses: 0, Win %: 0.476, GF: 180, GA: 117, Diff: 63
# Team: Edmonton Oilers, Year: 1994, Wins: 17, Losses: 27, OT Losses: 0, Win %: 0.476, GF: 136, GA: 183, Diff: -47
# ...

# %%
import pandas as pd

data = [
    {"Team": "Mighty Ducks of Anaheim", "Year": 1994, "Wins": 16, "Losses": 27, "Win %": 0.476, "GF": 125, "GA": 164, "Diff": -39},
    {"Team": "Boston Bruins", "Year": 1994, "Wins": 27, "Losses": 18, "Win %": 0.476, "GF": 150, "GA": 127, "Diff": 23},
    {"Team": "Buffalo Sabres", "Year": 1994, "Wins": 22, "Losses": 19, "Win %": 0.476, "GF": 130, "GA": 119, "Diff": 11},
    {"Team": "Calgary Flames", "Year": 1994, "Wins": 24, "Losses": 17, "Win %": 0.476, "GF": 163, "GA": 135, "Diff": 28},
    {"Team": "Chicago Blackhawks", "Year": 1994, "Wins": 24, "Losses": 19, "Win %": 0.476, "GF": 156, "GA": 115, "Diff": 41},
    {"Team": "Dallas Stars", "Year": 1994, "Wins": 17, "Losses": 23, "Win %": 0.476, "GF": 136, "GA": 135, "Diff": 1},
    {"Team": "Detroit Red Wings", "Year": 1994, "Wins": 33, "Losses": 11, "Win %": 0.476, "GF": 180, "GA": 117, "Diff": 63},
    {"Team": "Edmonton Oilers", "Year": 1994, "Wins": 17, "Losses": 27, "Win %": 0.476, "GF": 136, "GA": 183, "Diff": -47},
    {"Team": "Florida Panthers", "Year": 1994, "Wins": 20, "Losses": 22, "Win %": 0.476, "GF": 115, "GA": 127, "Diff": -12},
    {"Team": "Hartford Whalers", "Year": 1994, "Wins": 19, "Losses": 24, "Win %": 0.476, "GF": 127, "GA": 141, "Diff": -14},
    {"Team": "Los Angeles Kings", "Year": 1994, "Wins": 16, "Losses": 23, "Win %": 0.476, "GF": 142, "GA": 174, "Diff": -32},
    {"Team": "Montreal Canadiens", "Year": 1994, "Wins": 18, "Losses": 23, "Win %": 0.476, "GF": 125, "GA": 148, "Diff": -23},
    {"Team": "New Jersey Devils", "Year": 1994, "Wins": 22, "Losses": 18, "Win %": 0.476, "GF": 136, "GA": 121, "Diff": 15},
    {"Team": "New York Islanders", "Year": 1994, "Wins": 15, "Losses": 28, "Win %": 0.476, "GF": 126, "GA": 158, "Diff": -32},
    {"Team": "New York Rangers", "Year": 1994, "Wins": 22, "Losses": 23, "Win %": 0.476, "GF": 139, "GA": 134, "Diff": 5},
    {"Team": "Ottawa Senators", "Year": 1994, "Wins": 9, "Losses": 34, "Win %": 0.476, "GF": 117, "GA": 174, "Diff": -57},
    {"Team": "Philadelphia Flyers", "Year": 1994, "Wins": 28, "Losses": 16, "Win %": 0.476, "GF": 150, "GA": 132, "Diff": 18},
    {"Team": "Pittsburgh Penguins", "Year": 1994, "Wins": 29, "Losses": 16, "Win %": 0.476, "GF": 181, "GA": 158, "Diff": 23},
    {"Team": "Quebec Nordiques", "Year": 1994, "Wins": 30, "Losses": 13, "Win %": 0.476, "GF": 185, "GA": 134, "Diff": 51},
    {"Team": "San Jose Sharks", "Year": 1994, "Wins": 19, "Losses": 25, "Win %": 0.476, "GF": 129, "GA": 161, "Diff": -32},
    {"Team": "St. Louis Blues", "Year": 1994, "Wins": 28, "Losses": 15, "Win %": 0.476, "GF": 178, "GA": 135, "Diff": 43},
    {"Team": "Tampa Bay Lightning", "Year": 1994, "Wins": 17, "Losses": 28, "Win %": 0.476, "GF": 120, "GA": 144, "Diff": -24},
    {"Team": "Toronto Maple Leafs", "Year": 1994, "Wins": 21, "Losses": 19, "Win %": 0.476, "GF": 135, "GA": 146, "Diff": -11},
    {"Team": "Vancouver Canucks", "Year": 1994, "Wins": 18, "Losses": 18, "Win %": 0.476, "GF": 153, "GA": 148, "Diff": 5},
    {"Team": "Washington Capitals", "Year": 1994, "Wins": 22, "Losses": 18, "Win %": 0.476, "GF": 136, "GA": 120, "Diff": 16},
    {"Team": "Winnipeg Jets", "Year": 1994, "Wins": 16, "Losses": 25, "Win %": 0.476, "GF": 157, "GA": 177, "Diff": -20},
]

df = pd.DataFrame(data)
pd.set_option('display.max_rows', None)
print(df)
# Out:
#                        Team  Year  Wins  Losses  Win %   GF   GA  Diff
# 0   Mighty Ducks of Anaheim  1994    16      27  0.476  125  164   -39
# 1             Boston Bruins  1994    27      18  0.476  150  127    23
# 2            Buffalo Sabres  1994    22      19  0.476  130  119    11
# 3            Calgary Flames  1994    24      17  0.476  163  135    28
# 4        Chicago Blackhawks  1994    24      19  0.476  156  115    41
# 5              Dallas Stars  1994    17      23  0.476  136  135     1
# 6         Detroit Red Wings  1994    33      11  0.476  180  117    63
# 7           Edmonton Oilers  1994    17      27  0.476  136  183   -47
# 8          Florida Panthers  1994    20      22  0.476  115  127   -12
# 9          Hartford Whalers  1994    19      24  0.476  127  141   -14
# 10        Los Angeles Kings  1994    16      23  0.476  142  174   -32
# 11       Montreal Canadiens  1994    18      23  0.476  125  148   -23
# ...

# %% [markdown]
# <big><big><big><span style="color:orange; font-weight:bold;">1995</span>

# %%
from bs4 import BeautifulSoup
import requests
import time

url = "https://www.scrapethissite.com/pages/forms/?per_page=400"

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/115.0.0.0 Safari/537.36'
}

response = requests.get(url, headers=headers)
time.sleep(1)  # Jedna sekunda, aby server nebyl přetížen

# Pokud je stránka dostupná
if response.status_code == 200:
    soup = BeautifulSoup(response.text, 'html.parser')

    # Vyhledání všech řádků s třídou "team" 
    teams = soup.find_all('tr', class_='team')
    
    # Pro každý tým extrahujeme data
    for team in teams:
        year = team.find('td', class_='year').text.strip()
        
        # filtrujeme pouze týmy z roku 1990
        if year == '1995':
            name = team.find('td', class_='name').text.strip()
            wins = team.find('td', class_='wins').text.strip()
            losses = team.find('td', class_='losses').text.strip()
            goals_for = team.find('td', class_='gf').text.strip()  # goly vstřelené
            goals_against = team.find('td', class_='ga').text.strip()  # Góly obdržené
            diff = team.find('td', class_='diff').text.strip()  # Rozdíl skóre

            # Výpis dat pouze pro rok 1990
            print(f"Team: {name}, Year: {year}, Wins: {wins}, Losses: {losses}, OT Losses: {ot_losses}, Win %: {win_pct}, GF: {goals_for}, GA: {goals_against}, Diff: {diff}")
else:
    print("Chyba při načítání stránky:", response.status_code)
# Out:
# Team: Mighty Ducks of Anaheim, Year: 1995, Wins: 35, Losses: 39, OT Losses: 0, Win %: 0.476, GF: 234, GA: 247, Diff: -13
# Team: Boston Bruins, Year: 1995, Wins: 40, Losses: 31, OT Losses: 0, Win %: 0.476, GF: 282, GA: 269, Diff: 13
# Team: Buffalo Sabres, Year: 1995, Wins: 33, Losses: 42, OT Losses: 0, Win %: 0.476, GF: 247, GA: 262, Diff: -15
# Team: Calgary Flames, Year: 1995, Wins: 34, Losses: 37, OT Losses: 0, Win %: 0.476, GF: 241, GA: 240, Diff: 1
# Team: Chicago Blackhawks, Year: 1995, Wins: 40, Losses: 28, OT Losses: 0, Win %: 0.476, GF: 273, GA: 220, Diff: 53
# Team: Colorado Avalanche, Year: 1995, Wins: 47, Losses: 25, OT Losses: 0, Win %: 0.476, GF: 326, GA: 240, Diff: 86
# Team: Dallas Stars, Year: 1995, Wins: 26, Losses: 42, OT Losses: 0, Win %: 0.476, GF: 227, GA: 280, Diff: -53
# Team: Detroit Red Wings, Year: 1995, Wins: 62, Losses: 13, OT Losses: 0, Win %: 0.476, GF: 325, GA: 181, Diff: 144
# ...

# %%
import pandas as pd

data = [
    {"Team": "Mighty Ducks of Anaheim", "Year": 1995, "Wins": 35, "Losses": 39, "Win %": 0.476, "GF": 234, "GA": 247, "Diff": -13},
    {"Team": "Boston Bruins", "Year": 1995, "Wins": 40, "Losses": 31, "Win %": 0.476, "GF": 282, "GA": 269, "Diff": 13},
    {"Team": "Buffalo Sabres", "Year": 1995, "Wins": 33, "Losses": 42, "Win %": 0.476, "GF": 247, "GA": 262, "Diff": -15},
    {"Team": "Calgary Flames", "Year": 1995, "Wins": 34, "Losses": 37, "Win %": 0.476, "GF": 241, "GA": 240, "Diff": 1},
    {"Team": "Chicago Blackhawks", "Year": 1995, "Wins": 40, "Losses": 28, "Win %": 0.476, "GF": 273, "GA": 220, "Diff": 53},
    {"Team": "Colorado Avalanche", "Year": 1995, "Wins": 47, "Losses": 25, "Win %": 0.476, "GF": 326, "GA": 240, "Diff": 86},
    {"Team": "Dallas Stars", "Year": 1995, "Wins": 26, "Losses": 42, "Win %": 0.476, "GF": 227, "GA": 280, "Diff": -53},
    {"Team": "Detroit Red Wings", "Year": 1995, "Wins": 62, "Losses": 13, "Win %": 0.476, "GF": 325, "GA": 181, "Diff": 144},
    {"Team": "Edmonton Oilers", "Year": 1995, "Wins": 30, "Losses": 44, "Win %": 0.476, "GF": 240, "GA": 304, "Diff": -64},
    {"Team": "Florida Panthers", "Year": 1995, "Wins": 41, "Losses": 31, "Win %": 0.476, "GF": 254, "GA": 234, "Diff": 20},
    {"Team": "Hartford Whalers", "Year": 1995, "Wins": 34, "Losses": 39, "Win %": 0.476, "GF": 237, "GA": 259, "Diff": -22},
    {"Team": "Los Angeles Kings", "Year": 1995, "Wins": 24, "Losses": 40, "Win %": 0.476, "GF": 256, "GA": 302, "Diff": -46},
    {"Team": "Montreal Canadiens", "Year": 1995, "Wins": 40, "Losses": 32, "Win %": 0.476, "GF": 265, "GA": 248, "Diff": 17},
    {"Team": "New Jersey Devils", "Year": 1995, "Wins": 37, "Losses": 33, "Win %": 0.476, "GF": 215, "GA": 202, "Diff": 13},
    {"Team": "New York Islanders", "Year": 1995, "Wins": 22, "Losses": 50, "Win %": 0.476, "GF": 229, "GA": 315, "Diff": -86},
    {"Team": "New York Rangers", "Year": 1995, "Wins": 41, "Losses": 27, "Win %": 0.476, "GF": 272, "GA": 237, "Diff": 35},
    {"Team": "Ottawa Senators", "Year": 1995, "Wins": 18, "Losses": 59, "Win %": 0.476, "GF": 191, "GA": 291, "Diff": -100},
    {"Team": "Philadelphia Flyers", "Year": 1995, "Wins": 45, "Losses": 24, "Win %": 0.476, "GF": 282, "GA": 208, "Diff": 74},
    {"Team": "Pittsburgh Penguins", "Year": 1995, "Wins": 49, "Losses": 29, "Win %": 0.476, "GF": 362, "GA": 284, "Diff": 78},
    {"Team": "San Jose Sharks", "Year": 1995, "Wins": 20, "Losses": 55, "Win %": 0.476, "GF": 252, "GA": 357, "Diff": -105},
    {"Team": "St. Louis Blues", "Year": 1995, "Wins": 32, "Losses": 34, "Win %": 0.476, "GF": 219, "GA": 248, "Diff": -29},
    {"Team": "Tampa Bay Lightning", "Year": 1995, "Wins": 38, "Losses": 32, "Win %": 0.476, "GF": 238, "GA": 248, "Diff": -10},
    {"Team": "Toronto Maple Leafs", "Year": 1995, "Wins": 34, "Losses": 36, "Win %": 0.476, "GF": 247, "GA": 252, "Diff": -5},
    {"Team": "Vancouver Canucks", "Year": 1995, "Wins": 32, "Losses": 35, "Win %": 0.476, "GF": 278, "GA": 278, "Diff": 0},
    {"Team": "Washington Capitals", "Year": 1995, "Wins": 39, "Losses": 32, "Win %": 0.476, "GF": 234, "GA": 204, "Diff": 30},
    {"Team": "Winnipeg Jets", "Year": 1995, "Wins": 36, "Losses": 40, "Win %": 0.476, "GF": 275, "GA": 291, "Diff": -16},
]

df = pd.DataFrame(data)
pd.set_option('display.max_rows', None)
print(df)
# Out:
#                        Team  Year  Wins  Losses  Win %   GF   GA  Diff
# 0   Mighty Ducks of Anaheim  1995    35      39  0.476  234  247   -13
# 1             Boston Bruins  1995    40      31  0.476  282  269    13
# 2            Buffalo Sabres  1995    33      42  0.476  247  262   -15
# 3            Calgary Flames  1995    34      37  0.476  241  240     1
# 4        Chicago Blackhawks  1995    40      28  0.476  273  220    53
# 5        Colorado Avalanche  1995    47      25  0.476  326  240    86
# 6              Dallas Stars  1995    26      42  0.476  227  280   -53
# 7         Detroit Red Wings  1995    62      13  0.476  325  181   144
# 8           Edmonton Oilers  1995    30      44  0.476  240  304   -64
# 9          Florida Panthers  1995    41      31  0.476  254  234    20
# 10         Hartford Whalers  1995    34      39  0.476  237  259   -22
# 11        Los Angeles Kings  1995    24      40  0.476  256  302   -46
# ...

# %% [markdown]
# <big><big><big><span style="color:orange; font-weight:bold;">1996</span>

# %%
from bs4 import BeautifulSoup
import requests
import time

url = "https://www.scrapethissite.com/pages/forms/?per_page=400"

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/115.0.0.0 Safari/537.36'
}

response = requests.get(url, headers=headers)
time.sleep(1)  # Jedna sekunda, aby server nebyl přetížen

# Pokud je stránka dostupná
if response.status_code == 200:
    soup = BeautifulSoup(response.text, 'html.parser')

    # Vyhledání všech řádků s třídou "team" 
    teams = soup.find_all('tr', class_='team')
    
    # Pro každý tým extrahujeme data
    for team in teams:
        year = team.find('td', class_='year').text.strip()
        
        # filtrujeme pouze týmy z roku 1990
        if year == '1996':
            name = team.find('td', class_='name').text.strip()
            wins = team.find('td', class_='wins').text.strip()
            losses = team.find('td', class_='losses').text.strip()
            goals_for = team.find('td', class_='gf').text.strip()  # goly vstřelené
            goals_against = team.find('td', class_='ga').text.strip()  # Góly obdržené
            diff = team.find('td', class_='diff').text.strip()  # Rozdíl skóre

            # Výpis dat pouze pro rok 1990
            print(f"Team: {name}, Year: {year}, Wins: {wins}, Losses: {losses}, OT Losses: {ot_losses}, Win %: {win_pct}, GF: {goals_for}, GA: {goals_against}, Diff: {diff}")
else:
    print("Chyba při načítání stránky:", response.status_code)
# Out:
# Team: Mighty Ducks of Anaheim, Year: 1996, Wins: 36, Losses: 33, OT Losses: 0, Win %: 0.476, GF: 245, GA: 233, Diff: 12
# Team: Boston Bruins, Year: 1996, Wins: 26, Losses: 47, OT Losses: 0, Win %: 0.476, GF: 234, GA: 300, Diff: -66
# Team: Buffalo Sabres, Year: 1996, Wins: 40, Losses: 30, OT Losses: 0, Win %: 0.476, GF: 237, GA: 208, Diff: 29
# Team: Calgary Flames, Year: 1996, Wins: 32, Losses: 41, OT Losses: 0, Win %: 0.476, GF: 214, GA: 239, Diff: -25
# Team: Chicago Blackhawks, Year: 1996, Wins: 34, Losses: 35, OT Losses: 0, Win %: 0.476, GF: 223, GA: 210, Diff: 13
# Team: Colorado Avalanche, Year: 1996, Wins: 49, Losses: 24, OT Losses: 0, Win %: 0.476, GF: 277, GA: 205, Diff: 72
# Team: Dallas Stars, Year: 1996, Wins: 48, Losses: 26, OT Losses: 0, Win %: 0.476, GF: 252, GA: 198, Diff: 54
# Team: Detroit Red Wings, Year: 1996, Wins: 38, Losses: 26, OT Losses: 0, Win %: 0.476, GF: 253, GA: 197, Diff: 56
# ...

# %%
import pandas as pd

data = [
    {"Team": "Mighty Ducks of Anaheim", "Year": 1996, "Wins": 36, "Losses": 33, "Win %": 0.476, "GF": 245, "GA": 233, "Diff": 12},
    {"Team": "Boston Bruins", "Year": 1996, "Wins": 26, "Losses": 47, "Win %": 0.476, "GF": 234, "GA": 300, "Diff": -66},
    {"Team": "Buffalo Sabres", "Year": 1996, "Wins": 40, "Losses": 30, "Win %": 0.476, "GF": 237, "GA": 208, "Diff": 29},
    {"Team": "Calgary Flames", "Year": 1996, "Wins": 32, "Losses": 41, "Win %": 0.476, "GF": 214, "GA": 239, "Diff": -25},
    {"Team": "Chicago Blackhawks", "Year": 1996, "Wins": 34, "Losses": 35, "Win %": 0.476, "GF": 223, "GA": 210, "Diff": 13},
    {"Team": "Colorado Avalanche", "Year": 1996, "Wins": 49, "Losses": 24, "Win %": 0.476, "GF": 277, "GA": 205, "Diff": 72},
    {"Team": "Dallas Stars", "Year": 1996, "Wins": 48, "Losses": 26, "Win %": 0.476, "GF": 252, "GA": 198, "Diff": 54},
    {"Team": "Detroit Red Wings", "Year": 1996, "Wins": 38, "Losses": 26, "Win %": 0.476, "GF": 253, "GA": 197, "Diff": 56},
    {"Team": "Edmonton Oilers", "Year": 1996, "Wins": 36, "Losses": 37, "Win %": 0.476, "GF": 252, "GA": 247, "Diff": 5},
    {"Team": "Florida Panthers", "Year": 1996, "Wins": 35, "Losses": 28, "Win %": 0.476, "GF": 221, "GA": 201, "Diff": 20},
    {"Team": "Hartford Whalers", "Year": 1996, "Wins": 32, "Losses": 39, "Win %": 0.476, "GF": 226, "GA": 256, "Diff": -30},
    {"Team": "Los Angeles Kings", "Year": 1996, "Wins": 28, "Losses": 43, "Win %": 0.476, "GF": 214, "GA": 268, "Diff": -54},
    {"Team": "Montreal Canadiens", "Year": 1996, "Wins": 31, "Losses": 36, "Win %": 0.476, "GF": 249, "GA": 276, "Diff": -27},
    {"Team": "New Jersey Devils", "Year": 1996, "Wins": 45, "Losses": 23, "Win %": 0.476, "GF": 231, "GA": 182, "Diff": 49},
    {"Team": "New York Islanders", "Year": 1996, "Wins": 29, "Losses": 41, "Win %": 0.476, "GF": 240, "GA": 250, "Diff": -10},
    {"Team": "New York Rangers", "Year": 1996, "Wins": 38, "Losses": 34, "Win %": 0.476, "GF": 258, "GA": 231, "Diff": 27},
    {"Team": "Ottawa Senators", "Year": 1996, "Wins": 31, "Losses": 36, "Win %": 0.476, "GF": 226, "GA": 234, "Diff": -8},
    {"Team": "Philadelphia Flyers", "Year": 1996, "Wins": 45, "Losses": 24, "Win %": 0.476, "GF": 274, "GA": 217, "Diff": 57},
    {"Team": "Phoenix Coyotes", "Year": 1996, "Wins": 38, "Losses": 37, "Win %": 0.476, "GF": 240, "GA": 243, "Diff": -3},
    {"Team": "Pittsburgh Penguins", "Year": 1996, "Wins": 38, "Losses": 36, "Win %": 0.476, "GF": 285, "GA": 280, "Diff": 5},
    {"Team": "San Jose Sharks", "Year": 1996, "Wins": 27, "Losses": 47, "Win %": 0.476, "GF": 211, "GA": 278, "Diff": -67},
    {"Team": "St. Louis Blues", "Year": 1996, "Wins": 36, "Losses": 35, "Win %": 0.476, "GF": 236, "GA": 239, "Diff": -3},
    {"Team": "Tampa Bay Lightning", "Year": 1996, "Wins": 32, "Losses": 40, "Win %": 0.476, "GF": 217, "GA": 247, "Diff": -30},
    {"Team": "Toronto Maple Leafs", "Year": 1996, "Wins": 30, "Losses": 44, "Win %": 0.476, "GF": 230, "GA": 273, "Diff": -43},
    {"Team": "Vancouver Canucks", "Year": 1996, "Wins": 35, "Losses": 40, "Win %": 0.476, "GF": 257, "GA": 273, "Diff": -16},
    {"Team": "Washington Capitals", "Year": 1996, "Wins": 33, "Losses": 40, "Win %": 0.476, "GF": 214, "GA": 231, "Diff": -17},
]

df = pd.DataFrame(data)
pd.set_option('display.max_rows', None)
print(df)
# Out:
#                        Team  Year  Wins  Losses  Win %   GF   GA  Diff
# 0   Mighty Ducks of Anaheim  1996    36      33  0.476  245  233    12
# 1             Boston Bruins  1996    26      47  0.476  234  300   -66
# 2            Buffalo Sabres  1996    40      30  0.476  237  208    29
# 3            Calgary Flames  1996    32      41  0.476  214  239   -25
# 4        Chicago Blackhawks  1996    34      35  0.476  223  210    13
# 5        Colorado Avalanche  1996    49      24  0.476  277  205    72
# 6              Dallas Stars  1996    48      26  0.476  252  198    54
# 7         Detroit Red Wings  1996    38      26  0.476  253  197    56
# 8           Edmonton Oilers  1996    36      37  0.476  252  247     5
# 9          Florida Panthers  1996    35      28  0.476  221  201    20
# 10         Hartford Whalers  1996    32      39  0.476  226  256   -30
# 11        Los Angeles Kings  1996    28      43  0.476  214  268   -54
# ...

# %% [markdown]
# <big><big><big><span style="color:orange; font-weight:bold;">1997</span>

# %%
from bs4 import BeautifulSoup
import requests
import time

url = "https://www.scrapethissite.com/pages/forms/?per_page=400"

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/115.0.0.0 Safari/537.36'
}

response = requests.get(url, headers=headers)
time.sleep(1)  # Jedna sekunda, aby server nebyl přetížen

# Pokud je stránka dostupná
if response.status_code == 200:
    soup = BeautifulSoup(response.text, 'html.parser')

    # Vyhledání všech řádků s třídou "team" 
    teams = soup.find_all('tr', class_='team')
    
    # Pro každý tým extrahujeme data
    for team in teams:
        year = team.find('td', class_='year').text.strip()
        
        # filtrujeme pouze týmy z roku 1990
        if year == '1997':
            name = team.find('td', class_='name').text.strip()
            wins = team.find('td', class_='wins').text.strip()
            losses = team.find('td', class_='losses').text.strip()
            goals_for = team.find('td', class_='gf').text.strip()  # goly vstřelené
            goals_against = team.find('td', class_='ga').text.strip()  # Góly obdržené
            diff = team.find('td', class_='diff').text.strip()  # Rozdíl skóre

            # Výpis dat pouze pro rok 1990
            print(f"Team: {name}, Year: {year}, Wins: {wins}, Losses: {losses}, Win %: {win_pct}, GF: {goals_for}, GA: {goals_against}, Diff: {diff}")
else:
    print("Chyba při načítání stránky:", response.status_code)
# Out:
# Team: Mighty Ducks of Anaheim, Year: 1997, Wins: 26, Losses: 43, Win %: 0.412, GF: 205, GA: 261, Diff: -56
# Team: Boston Bruins, Year: 1997, Wins: 39, Losses: 30, Win %: 0.412, GF: 221, GA: 194, Diff: 27
# Team: Buffalo Sabres, Year: 1997, Wins: 36, Losses: 29, Win %: 0.412, GF: 211, GA: 187, Diff: 24
# Team: Calgary Flames, Year: 1997, Wins: 26, Losses: 41, Win %: 0.412, GF: 217, GA: 252, Diff: -35
# Team: Carolina Hurricanes, Year: 1997, Wins: 33, Losses: 41, Win %: 0.412, GF: 200, GA: 219, Diff: -19
# Team: Chicago Blackhawks, Year: 1997, Wins: 30, Losses: 39, Win %: 0.412, GF: 192, GA: 199, Diff: -7
# Team: Colorado Avalanche, Year: 1997, Wins: 39, Losses: 26, Win %: 0.412, GF: 231, GA: 205, Diff: 26
# Team: Dallas Stars, Year: 1997, Wins: 49, Losses: 22, Win %: 0.412, GF: 242, GA: 167, Diff: 75
# Team: Detroit Red Wings, Year: 1997, Wins: 44, Losses: 23, Win %: 0.412, GF: 250, GA: 196, Diff: 54
# ...

# %%
import pandas as pd

data = [
    {"Team": "Mighty Ducks of Anaheim", "Year": 1997, "Wins": 26, "Losses": 43, "Win %": 0.412, "GF": 205, "GA": 261, "Diff": -56},
    {"Team": "Boston Bruins", "Year": 1997, "Wins": 39, "Losses": 30, "Win %": 0.412, "GF": 221, "GA": 194, "Diff": 27},
    {"Team": "Buffalo Sabres", "Year": 1997, "Wins": 36, "Losses": 29, "Win %": 0.412, "GF": 211, "GA": 187, "Diff": 24},
    {"Team": "Calgary Flames", "Year": 1997, "Wins": 26, "Losses": 41, "Win %": 0.412, "GF": 217, "GA": 252, "Diff": -35},
    {"Team": "Carolina Hurricanes", "Year": 1997, "Wins": 33, "Losses": 41, "Win %": 0.412, "GF": 200, "GA": 219, "Diff": -19},
    {"Team": "Chicago Blackhawks", "Year": 1997, "Wins": 30, "Losses": 39, "Win %": 0.412, "GF": 192, "GA": 199, "Diff": -7},
    {"Team": "Colorado Avalanche", "Year": 1997, "Wins": 39, "Losses": 26, "Win %": 0.412, "GF": 231, "GA": 205, "Diff": 26},
    {"Team": "Dallas Stars", "Year": 1997, "Wins": 49, "Losses": 22, "Win %": 0.412, "GF": 242, "GA": 167, "Diff": 75},
    {"Team": "Detroit Red Wings", "Year": 1997, "Wins": 44, "Losses": 23, "Win %": 0.412, "GF": 250, "GA": 196, "Diff": 54},
    {"Team": "Edmonton Oilers", "Year": 1997, "Wins": 35, "Losses": 37, "Win %": 0.412, "GF": 215, "GA": 224, "Diff": -9},
    {"Team": "Florida Panthers", "Year": 1997, "Wins": 24, "Losses": 43, "Win %": 0.412, "GF": 203, "GA": 256, "Diff": -53},
    {"Team": "Los Angeles Kings", "Year": 1997, "Wins": 38, "Losses": 33, "Win %": 0.412, "GF": 227, "GA": 225, "Diff": 2},
    {"Team": "Montreal Canadiens", "Year": 1997, "Wins": 37, "Losses": 32, "Win %": 0.412, "GF": 235, "GA": 208, "Diff": 27},
    {"Team": "New Jersey Devils", "Year": 1997, "Wins": 48, "Losses": 23, "Win %": 0.412, "GF": 225, "GA": 166, "Diff": 59},
    {"Team": "New York Islanders", "Year": 1997, "Wins": 30, "Losses": 41, "Win %": 0.412, "GF": 212, "GA": 225, "Diff": -13},
    {"Team": "New York Rangers", "Year": 1997, "Wins": 25, "Losses": 39, "Win %": 0.412, "GF": 197, "GA": 231, "Diff": -34},
    {"Team": "Ottawa Senators", "Year": 1997, "Wins": 34, "Losses": 33, "Win %": 0.412, "GF": 193, "GA": 200, "Diff": -7},
    {"Team": "Philadelphia Flyers", "Year": 1997, "Wins": 42, "Losses": 29, "Win %": 0.412, "GF": 242, "GA": 193, "Diff": 49},
    {"Team": "Phoenix Coyotes", "Year": 1997, "Wins": 35, "Losses": 35, "Win %": 0.412, "GF": 224, "GA": 227, "Diff": -3},
    {"Team": "Pittsburgh Penguins", "Year": 1997, "Wins": 40, "Losses": 24, "Win %": 0.412, "GF": 228, "GA": 188, "Diff": 40},
    {"Team": "San Jose Sharks", "Year": 1997, "Wins": 34, "Losses": 38, "Win %": 0.412, "GF": 210, "GA": 216, "Diff": -6},
    {"Team": "St. Louis Blues", "Year": 1997, "Wins": 45, "Losses": 29, "Win %": 0.412, "GF": 256, "GA": 204, "Diff": 52},
    {"Team": "Tampa Bay Lightning", "Year": 1997, "Wins": 17, "Losses": 55, "Win %": 0.412, "GF": 151, "GA": 269, "Diff": -118},
    {"Team": "Toronto Maple Leafs", "Year": 1997, "Wins": 30, "Losses": 43, "Win %": 0.412, "GF": 194, "GA": 237, "Diff": -43},
    {"Team": "Vancouver Canucks", "Year": 1997, "Wins": 25, "Losses": 43, "Win %": 0.412, "GF": 224, "GA": 273, "Diff": -49},
    {"Team": "Washington Capitals", "Year": 1997, "Wins": 40, "Losses": 30, "Win %": 0.412, "GF": 219, "GA": 202, "Diff": 17},
]

df = pd.DataFrame(data)
pd.set_option('display.max_rows', None)
print(df)
# Out:
#                        Team  Year  Wins  Losses  Win %   GF   GA  Diff
# 0   Mighty Ducks of Anaheim  1997    26      43  0.412  205  261   -56
# 1             Boston Bruins  1997    39      30  0.412  221  194    27
# 2            Buffalo Sabres  1997    36      29  0.412  211  187    24
# 3            Calgary Flames  1997    26      41  0.412  217  252   -35
# 4       Carolina Hurricanes  1997    33      41  0.412  200  219   -19
# 5        Chicago Blackhawks  1997    30      39  0.412  192  199    -7
# 6        Colorado Avalanche  1997    39      26  0.412  231  205    26
# 7              Dallas Stars  1997    49      22  0.412  242  167    75
# 8         Detroit Red Wings  1997    44      23  0.412  250  196    54
# 9           Edmonton Oilers  1997    35      37  0.412  215  224    -9
# 10         Florida Panthers  1997    24      43  0.412  203  256   -53
# 11        Los Angeles Kings  1997    38      33  0.412  227  225     2
# ...

# %% [markdown]
# <big><big><big><span style="color:orange; font-weight:bold;">1998</span>

# %%
from bs4 import BeautifulSoup
import requests
import time

url = "https://www.scrapethissite.com/pages/forms/?per_page=400"

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/115.0.0.0 Safari/537.36'
}

response = requests.get(url, headers=headers)
time.sleep(1)  # Jedna sekunda, aby server nebyl přetížen

# Pokud je stránka dostupná
if response.status_code == 200:
    soup = BeautifulSoup(response.text, 'html.parser')

    # Vyhledání všech řádků s třídou "team" 
    teams = soup.find_all('tr', class_='team')
    
    # Pro každý tým extrahujeme data
    for team in teams:
        year = team.find('td', class_='year').text.strip()
        
        # filtrujeme pouze týmy z roku 1990
        if year == '1998':
            name = team.find('td', class_='name').text.strip()
            wins = team.find('td', class_='wins').text.strip()
            losses = team.find('td', class_='losses').text.strip()
            goals_for = team.find('td', class_='gf').text.strip()  # goly vstřelené
            goals_against = team.find('td', class_='ga').text.strip()  # Góly obdržené
            diff = team.find('td', class_='diff').text.strip()  # Rozdíl skóre

            # Výpis dat pouze pro rok 1990
            print(f"Team: {name}, Year: {year}, Wins: {wins}, Losses: {losses}, GF: {goals_for}, GA: {goals_against}, Diff: {diff}")
else:
    print("Chyba při načítání stránky:", response.status_code)
# Out:
# Team: Mighty Ducks of Anaheim, Year: 1998, Wins: 35, Losses: 34, GF: 215, GA: 206, Diff: 9
# Team: Boston Bruins, Year: 1998, Wins: 39, Losses: 30, GF: 214, GA: 181, Diff: 33
# Team: Buffalo Sabres, Year: 1998, Wins: 37, Losses: 28, GF: 207, GA: 175, Diff: 32
# Team: Calgary Flames, Year: 1998, Wins: 30, Losses: 40, GF: 211, GA: 234, Diff: -23
# Team: Carolina Hurricanes, Year: 1998, Wins: 34, Losses: 30, GF: 210, GA: 202, Diff: 8
# Team: Chicago Blackhawks, Year: 1998, Wins: 29, Losses: 41, GF: 202, GA: 248, Diff: -46
# Team: Colorado Avalanche, Year: 1998, Wins: 44, Losses: 28, GF: 239, GA: 205, Diff: 34
# Team: Dallas Stars, Year: 1998, Wins: 51, Losses: 19, GF: 236, GA: 168, Diff: 68
# Team: Detroit Red Wings, Year: 1998, Wins: 43, Losses: 32, GF: 245, GA: 202, Diff: 43
# Team: Edmonton Oilers, Year: 1998, Wins: 33, Losses: 37, GF: 230, GA: 226, Diff: 4
# Team: Florida Panthers, Year: 1998, Wins: 30, Losses: 34, GF: 210, GA: 228, Diff: -18
# ...

# %%
import pandas as pd

data = [
    {"Team": "Mighty Ducks of Anaheim", "Year": 1998, "Wins": 35, "Losses": 34, "Win %": 0.412, "GF": 215, "GA": 206, "Diff": 9},
    {"Team": "Boston Bruins", "Year": 1998, "Wins": 39, "Losses": 30, "Win %": 0.412, "GF": 214, "GA": 181, "Diff": 33},
    {"Team": "Buffalo Sabres", "Year": 1998, "Wins": 37, "Losses": 28, "Win %": 0.412, "GF": 207, "GA": 175, "Diff": 32},
    {"Team": "Calgary Flames", "Year": 1998, "Wins": 30, "Losses": 40, "Win %": 0.412, "GF": 211, "GA": 234, "Diff": -23},
    {"Team": "Carolina Hurricanes", "Year": 1998, "Wins": 34, "Losses": 30, "Win %": 0.412, "GF": 210, "GA": 202, "Diff": 8},
    {"Team": "Chicago Blackhawks", "Year": 1998, "Wins": 29, "Losses": 41, "Win %": 0.412, "GF": 202, "GA": 248, "Diff": -46},
    {"Team": "Colorado Avalanche", "Year": 1998, "Wins": 44, "Losses": 28, "Win %": 0.412, "GF": 239, "GA": 205, "Diff": 34},
    {"Team": "Dallas Stars", "Year": 1998, "Wins": 51, "Losses": 19, "Win %": 0.412, "GF": 236, "GA": 168, "Diff": 68},
    {"Team": "Detroit Red Wings", "Year": 1998, "Wins": 43, "Losses": 32, "Win %": 0.412, "GF": 245, "GA": 202, "Diff": 43},
    {"Team": "Edmonton Oilers", "Year": 1998, "Wins": 33, "Losses": 37, "Win %": 0.412, "GF": 230, "GA": 226, "Diff": 4},
    {"Team": "Florida Panthers", "Year": 1998, "Wins": 30, "Losses": 34, "Win %": 0.412, "GF": 210, "GA": 228, "Diff": -18},
    {"Team": "Los Angeles Kings", "Year": 1998, "Wins": 32, "Losses": 45, "Win %": 0.412, "GF": 189, "GA": 222, "Diff": -33},
    {"Team": "Montreal Canadiens", "Year": 1998, "Wins": 32, "Losses": 39, "Win %": 0.412, "GF": 184, "GA": 209, "Diff": -25},
    {"Team": "Nashville Predators", "Year": 1998, "Wins": 28, "Losses": 47, "Win %": 0.412, "GF": 190, "GA": 261, "Diff": -71},
    {"Team": "New Jersey Devils", "Year": 1998, "Wins": 47, "Losses": 24, "Win %": 0.412, "GF": 248, "GA": 196, "Diff": 52},
    {"Team": "New York Islanders", "Year": 1998, "Wins": 24, "Losses": 48, "Win %": 0.412, "GF": 194, "GA": 244, "Diff": -50},
    {"Team": "New York Rangers", "Year": 1998, "Wins": 33, "Losses": 38, "Win %": 0.412, "GF": 217, "GA": 227, "Diff": -10},
    {"Team": "Ottawa Senators", "Year": 1998, "Wins": 44, "Losses": 23, "Win %": 0.412, "GF": 239, "GA": 179, "Diff": 60},
    {"Team": "Philadelphia Flyers", "Year": 1998, "Wins": 37, "Losses": 26, "Win %": 0.412, "GF": 231, "GA": 196, "Diff": 35},
    {"Team": "Phoenix Coyotes", "Year": 1998, "Wins": 39, "Losses": 31, "Win %": 0.412, "GF": 205, "GA": 197, "Diff": 8},
    {"Team": "Pittsburgh Penguins", "Year": 1998, "Wins": 38, "Losses": 30, "Win %": 0.412, "GF": 242, "GA": 225, "Diff": 17},
    {"Team": "San Jose Sharks", "Year": 1998, "Wins": 31, "Losses": 33, "Win %": 0.412, "GF": 196, "GA": 191, "Diff": 5},
    {"Team": "St. Louis Blues", "Year": 1998, "Wins": 37, "Losses": 32, "Win %": 0.412, "GF": 237, "GA": 209, "Diff": 28},
    {"Team": "Tampa Bay Lightning", "Year": 1998, "Wins": 19, "Losses": 54, "Win %": 0.412, "GF": 179, "GA": 292, "Diff": -113},
    {"Team": "Toronto Maple Leafs", "Year": 1998, "Wins": 45, "Losses": 30, "Win %": 0.412, "GF": 268, "GA": 231, "Diff": 37},
    {"Team": "Vancouver Canucks", "Year": 1998, "Wins": 23, "Losses": 47, "Win %": 0.412, "GF": 192, "GA": 258, "Diff": -66},
    {"Team": "Washington Capitals", "Year": 1998, "Wins": 31, "Losses": 45, "Win %": 0.412, "GF": 200, "GA": 218, "Diff": -18},
]

df = pd.DataFrame(data)
pd.set_option('display.max_rows', None)
print(df)
# Out:
#                        Team  Year  Wins  Losses  Win %   GF   GA  Diff
# 0   Mighty Ducks of Anaheim  1998    35      34  0.412  215  206     9
# 1             Boston Bruins  1998    39      30  0.412  214  181    33
# 2            Buffalo Sabres  1998    37      28  0.412  207  175    32
# 3            Calgary Flames  1998    30      40  0.412  211  234   -23
# 4       Carolina Hurricanes  1998    34      30  0.412  210  202     8
# 5        Chicago Blackhawks  1998    29      41  0.412  202  248   -46
# 6        Colorado Avalanche  1998    44      28  0.412  239  205    34
# 7              Dallas Stars  1998    51      19  0.412  236  168    68
# 8         Detroit Red Wings  1998    43      32  0.412  245  202    43
# 9           Edmonton Oilers  1998    33      37  0.412  230  226     4
# 10         Florida Panthers  1998    30      34  0.412  210  228   -18
# 11        Los Angeles Kings  1998    32      45  0.412  189  222   -33
# ...

# %% [markdown]
# <big><big><big><span style="color:orange; font-weight:bold;">1999</span>

# %%
from bs4 import BeautifulSoup
import requests
import time

url = "https://www.scrapethissite.com/pages/forms/?per_page=400"

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/115.0.0.0 Safari/537.36'
}

response = requests.get(url, headers=headers)
time.sleep(1)  # Jedna sekunda, aby server nebyl přetížen

# Pokud je stránka dostupná
if response.status_code == 200:
    soup = BeautifulSoup(response.text, 'html.parser')

    # Vyhledání všech řádků s třídou "team" 
    teams = soup.find_all('tr', class_='team')
    
    # Pro každý tým extrahujeme data
    for team in teams:
        year = team.find('td', class_='year').text.strip()
        
        if year == '1999':
            name = team.find('td', class_='name').text.strip()
            wins = team.find('td', class_='wins').text.strip()
            losses = team.find('td', class_='losses').text.strip()
            goals_for = team.find('td', class_='gf').text.strip()  # goly vstřelené
            goals_against = team.find('td', class_='ga').text.strip()  # Góly obdržené
            diff = team.find('td', class_='diff').text.strip()  # Rozdíl skóre

            # Výpis dat pouze pro rok 1990
            print(f"Team: {name}, Year: {year}, Wins: {wins}, Losses: {losses}, Win %: {win_pct}, GF: {goals_for}, GA: {goals_against}, Diff: {diff}")
else:
    print("Chyba při načítání stránky:", response.status_code)
# Out:
# Team: Mighty Ducks of Anaheim, Year: 1999, Wins: 34, Losses: 33, Win %: 0.412, GF: 217, GA: 227, Diff: -10
# Team: Atlanta Thrashers, Year: 1999, Wins: 14, Losses: 57, Win %: 0.412, GF: 170, GA: 313, Diff: -143
# Team: Boston Bruins, Year: 1999, Wins: 24, Losses: 33, Win %: 0.412, GF: 210, GA: 248, Diff: -38
# Team: Buffalo Sabres, Year: 1999, Wins: 35, Losses: 32, Win %: 0.412, GF: 213, GA: 204, Diff: 9
# Team: Calgary Flames, Year: 1999, Wins: 31, Losses: 36, Win %: 0.412, GF: 211, GA: 256, Diff: -45
# Team: Carolina Hurricanes, Year: 1999, Wins: 37, Losses: 35, Win %: 0.412, GF: 217, GA: 216, Diff: 1
# Team: Chicago Blackhawks, Year: 1999, Wins: 33, Losses: 37, Win %: 0.412, GF: 242, GA: 245, Diff: -3
# Team: Colorado Avalanche, Year: 1999, Wins: 42, Losses: 28, Win %: 0.412, GF: 233, GA: 201, Diff: 32
# Team: Dallas Stars, Year: 1999, Wins: 43, Losses: 23, Win %: 0.412, GF: 211, GA: 184, Diff: 27
# ...

# %%
import pandas as pd

data = [
    {"Team": "Mighty Ducks of Anaheim", "Year": 1999, "Wins": 34, "Losses": 33, "Win %": 0.412, "GF": 217, "GA": 227, "Diff": -10},
    {"Team": "Atlanta Thrashers", "Year": 1999, "Wins": 14, "Losses": 57, "Win %": 0.412, "GF": 170, "GA": 313, "Diff": -143},
    {"Team": "Boston Bruins", "Year": 1999, "Wins": 24, "Losses": 33, "Win %": 0.412, "GF": 210, "GA": 248, "Diff": -38},
    {"Team": "Buffalo Sabres", "Year": 1999, "Wins": 35, "Losses": 32, "Win %": 0.412, "GF": 213, "GA": 204, "Diff": 9},
    {"Team": "Calgary Flames", "Year": 1999, "Wins": 31, "Losses": 36, "Win %": 0.412, "GF": 211, "GA": 256, "Diff": -45},
    {"Team": "Carolina Hurricanes", "Year": 1999, "Wins": 37, "Losses": 35, "Win %": 0.412, "GF": 217, "GA": 216, "Diff": 1},
    {"Team": "Chicago Blackhawks", "Year": 1999, "Wins": 33, "Losses": 37, "Win %": 0.412, "GF": 242, "GA": 245, "Diff": -3},
    {"Team": "Colorado Avalanche", "Year": 1999, "Wins": 42, "Losses": 28, "Win %": 0.412, "GF": 233, "GA": 201, "Diff": 32},
    {"Team": "Dallas Stars", "Year": 1999, "Wins": 43, "Losses": 23, "Win %": 0.412, "GF": 211, "GA": 184, "Diff": 27},
    {"Team": "Detroit Red Wings", "Year": 1999, "Wins": 48, "Losses": 22, "Win %": 0.412, "GF": 278, "GA": 210, "Diff": 68},
    {"Team": "Edmonton Oilers", "Year": 1999, "Wins": 32, "Losses": 26, "Win %": 0.412, "GF": 226, "GA": 212, "Diff": 14},
    {"Team": "Florida Panthers", "Year": 1999, "Wins": 43, "Losses": 27, "Win %": 0.412, "GF": 244, "GA": 209, "Diff": 35},
    {"Team": "Los Angeles Kings", "Year": 1999, "Wins": 39, "Losses": 27, "Win %": 0.412, "GF": 245, "GA": 228, "Diff": 17},
    {"Team": "Montreal Canadiens", "Year": 1999, "Wins": 35, "Losses": 34, "Win %": 0.412, "GF": 196, "GA": 194, "Diff": 2},
    {"Team": "Nashville Predators", "Year": 1999, "Wins": 28, "Losses": 40, "Win %": 0.412, "GF": 199, "GA": 240, "Diff": -41},
    {"Team": "New Jersey Devils", "Year": 1999, "Wins": 45, "Losses": 24, "Win %": 0.412, "GF": 251, "GA": 203, "Diff": 48},
    {"Team": "New York Islanders", "Year": 1999, "Wins": 24, "Losses": 48, "Win %": 0.412, "GF": 194, "GA": 275, "Diff": -81},
    {"Team": "New York Rangers", "Year": 1999, "Wins": 29, "Losses": 38, "Win %": 0.412, "GF": 218, "GA": 246, "Diff": -28},
    {"Team": "Ottawa Senators", "Year": 1999, "Wins": 41, "Losses": 28, "Win %": 0.412, "GF": 244, "GA": 210, "Diff": 34},
    {"Team": "Philadelphia Flyers", "Year": 1999, "Wins": 45, "Losses": 22, "Win %": 0.412, "GF": 237, "GA": 179, "Diff": 58},
    {"Team": "Phoenix Coyotes", "Year": 1999, "Wins": 39, "Losses": 31, "Win %": 0.412, "GF": 232, "GA": 228, "Diff": 4},
    {"Team": "Pittsburgh Penguins", "Year": 1999, "Wins": 37, "Losses": 31, "Win %": 0.412, "GF": 241, "GA": 236, "Diff": 5},
    {"Team": "San Jose Sharks", "Year": 1999, "Wins": 35, "Losses": 30, "Win %": 0.412, "GF": 225, "GA": 214, "Diff": 11},
    {"Team": "St. Louis Blues", "Year": 1999, "Wins": 51, "Losses": 19, "Win %": 0.412, "GF": 248, "GA": 165, "Diff": 83},
    {"Team": "Tampa Bay Lightning", "Year": 1999, "Wins": 19, "Losses": 47, "Win %": 0.412, "GF": 204, "GA": 310, "Diff": -106},
    {"Team": "Toronto Maple Leafs", "Year": 1999, "Wins": 45, "Losses": 27, "Win %": 0.412, "GF": 246, "GA": 222, "Diff": 24},
    {"Team": "Vancouver Canucks", "Year": 1999, "Wins": 30, "Losses": 29, "Win %": 0.412, "GF": 227, "GA": 237, "Diff": -10},
    {"Team": "Washington Capitals", "Year": 1999, "Wins": 44, "Losses": 24, "Win %": 0.412, "GF": 227, "GA": 194, "Diff": 33},
]

df = pd.DataFrame(data)
pd.set_option('display.max_rows', None)
print(df)
# Out:
#                        Team  Year  Wins  Losses  Win %   GF   GA  Diff
# 0   Mighty Ducks of Anaheim  1999    34      33  0.412  217  227   -10
# 1         Atlanta Thrashers  1999    14      57  0.412  170  313  -143
# 2             Boston Bruins  1999    24      33  0.412  210  248   -38
# 3            Buffalo Sabres  1999    35      32  0.412  213  204     9
# 4            Calgary Flames  1999    31      36  0.412  211  256   -45
# 5       Carolina Hurricanes  1999    37      35  0.412  217  216     1
# 6        Chicago Blackhawks  1999    33      37  0.412  242  245    -3
# 7        Colorado Avalanche  1999    42      28  0.412  233  201    32
# 8              Dallas Stars  1999    43      23  0.412  211  184    27
# 9         Detroit Red Wings  1999    48      22  0.412  278  210    68
# 10          Edmonton Oilers  1999    32      26  0.412  226  212    14
# 11         Florida Panthers  1999    43      27  0.412  244  209    35
# ...

# %% [markdown]
# <big><big><big><span style="color:orange; font-weight:bold;">2000</span>

# %%
from bs4 import BeautifulSoup
import requests
import time

url = "https://www.scrapethissite.com/pages/forms/?per_page=400"
pd.set_option('display.max_rows', None)  
pd.set_option('display.width', 1000) 

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/115.0.0.0 Safari/537.36'
}

response = requests.get(url, headers=headers)
time.sleep(1)  # Jedna sekunda, aby server nebyl přetížen

# Pokud je stránka dostupná
if response.status_code == 200:
    soup = BeautifulSoup(response.text, 'html.parser')

    # Vyhledání všech řádků s třídou "team" 
    teams = soup.find_all('tr', class_='team')
    
    # Pro každý tým extrahujeme data
    for team in teams:
        year = team.find('td', class_='year').text.strip()
        
      
        if year == '2000':
            name = team.find('td', class_='name').text.strip()
            wins = team.find('td', class_='wins').text.strip()
            losses = team.find('td', class_='losses').text.strip()
            goals_for = team.find('td', class_='gf').text.strip()  
            goals_against = team.find('td', class_='ga').text.strip()  
            diff = team.find('td', class_='diff').text.strip()  

            # Výpis dat pouze pro rok 1990
            print(f"Team: {name}, Year: {year}, Wins: {wins}, Losses: {losses}, Win %: {win_pct}, GF: {goals_for}, GA: {goals_against}, Diff: {diff}")
            df.to_csv('nhl_data_2000.csv', index=False)
else:
    print("Chyba při načítání stránky:", response.status_code)
    df.to_csv('nhl_data_2000.csv', index=False)
    print(df.to_string())
    pd.set_option('display.max_rows', None)
# Out:
# Team: Mighty Ducks of Anaheim, Year: 2000, Wins: 25, Losses: 41, Win %: 0.412, GF: 188, GA: 245, Diff: -57
# Team: Atlanta Thrashers, Year: 2000, Wins: 23, Losses: 45, Win %: 0.412, GF: 211, GA: 289, Diff: -78
# Team: Boston Bruins, Year: 2000, Wins: 36, Losses: 30, Win %: 0.412, GF: 227, GA: 249, Diff: -22
# Team: Buffalo Sabres, Year: 2000, Wins: 46, Losses: 30, Win %: 0.412, GF: 218, GA: 184, Diff: 34
# Team: Calgary Flames, Year: 2000, Wins: 27, Losses: 36, Win %: 0.412, GF: 197, GA: 236, Diff: -39
# Team: Carolina Hurricanes, Year: 2000, Wins: 38, Losses: 32, Win %: 0.412, GF: 212, GA: 225, Diff: -13
# Team: Columbus Blue Jackets, Year: 2000, Wins: 28, Losses: 39, Win %: 0.412, GF: 190, GA: 233, Diff: -43
# Team: Chicago Blackhawks, Year: 2000, Wins: 29, Losses: 40, Win %: 0.412, GF: 210, GA: 246, Diff: -36
# Team: Colorado Avalanche, Year: 2000, Wins: 52, Losses: 16, Win %: 0.412, GF: 270, GA: 192, Diff: 78
# ...

# %%
import pandas as pd

data = [
    {"Team": "Mighty Ducks of Anaheim", "Year": 2000, "Wins": 25, "Losses": 41, "Win %": 0.412, "GF": 188, "GA": 245, "Diff": -57},
    {"Team": "Atlanta Thrashers", "Year": 2000, "Wins": 23, "Losses": 45, "Win %": 0.412, "GF": 211, "GA": 289, "Diff": -78},
    {"Team": "Boston Bruins", "Year": 2000, "Wins": 36, "Losses": 30, "Win %": 0.412, "GF": 227, "GA": 249, "Diff": -22},
    {"Team": "Buffalo Sabres", "Year": 2000, "Wins": 46, "Losses": 30, "Win %": 0.412, "GF": 218, "GA": 184, "Diff": 34},
    {"Team": "Calgary Flames", "Year": 2000, "Wins": 27, "Losses": 36, "Win %": 0.412, "GF": 197, "GA": 236, "Diff": -39},
    {"Team": "Carolina Hurricanes", "Year": 2000, "Wins": 38, "Losses": 32, "Win %": 0.412, "GF": 212, "GA": 225, "Diff": -13},
    {"Team": "Columbus Blue Jackets", "Year": 2000, "Wins": 28, "Losses": 39, "Win %": 0.412, "GF": 190, "GA": 233, "Diff": -43},
    {"Team": "Chicago Blackhawks", "Year": 2000, "Wins": 29, "Losses": 40, "Win %": 0.412, "GF": 210, "GA": 246, "Diff": -36},
    {"Team": "Colorado Avalanche", "Year": 2000, "Wins": 52, "Losses": 16, "Win %": 0.412, "GF": 270, "GA": 192, "Diff": 78},
    {"Team": "Dallas Stars", "Year": 2000, "Wins": 48, "Losses": 24, "Win %": 0.412, "GF": 241, "GA": 187, "Diff": 54},
    {"Team": "Detroit Red Wings", "Year": 2000, "Wins": 49, "Losses": 20, "Win %": 0.412, "GF": 253, "GA": 202, "Diff": 51},
    {"Team": "Edmonton Oilers", "Year": 2000, "Wins": 39, "Losses": 28, "Win %": 0.412, "GF": 243, "GA": 222, "Diff": 21},
    {"Team": "Florida Panthers", "Year": 2000, "Wins": 22, "Losses": 38, "Win %": 0.412, "GF": 200, "GA": 246, "Diff": -46},
    {"Team": "Los Angeles Kings", "Year": 2000, "Wins": 38, "Losses": 28, "Win %": 0.412, "GF": 252, "GA": 228, "Diff": 24},
    {"Team": "Minnesota Wild", "Year": 2000, "Wins": 25, "Losses": 39, "Win %": 0.412, "GF": 168, "GA": 210, "Diff": -42},
    {"Team": "Montreal Canadiens", "Year": 2000, "Wins": 28, "Losses": 40, "Win %": 0.412, "GF": 206, "GA": 232, "Diff": -26},
    {"Team": "Nashville Predators", "Year": 2000, "Wins": 34, "Losses": 36, "Win %": 0.412, "GF": 186, "GA": 200, "Diff": -14},
    {"Team": "New Jersey Devils", "Year": 2000, "Wins": 48, "Losses": 19, "Win %": 0.412, "GF": 295, "GA": 195, "Diff": 100},
    {"Team": "New York Islanders", "Year": 2000, "Wins": 21, "Losses": 51, "Win %": 0.412, "GF": 185, "GA": 268, "Diff": -83},
    {"Team": "New York Rangers", "Year": 2000, "Wins": 33, "Losses": 43, "Win %": 0.412, "GF": 250, "GA": 290, "Diff": -40},
    {"Team": "Ottawa Senators", "Year": 2000, "Wins": 48, "Losses": 21, "Win %": 0.412, "GF": 274, "GA": 205, "Diff": 69},
    {"Team": "Philadelphia Flyers", "Year": 2000, "Wins": 43, "Losses": 25, "Win %": 0.412, "GF": 240, "GA": 207, "Diff": 33},
    {"Team": "Phoenix Coyotes", "Year": 2000, "Wins": 35, "Losses": 27, "Win %": 0.412, "GF": 214, "GA": 212, "Diff": 2},
    {"Team": "Pittsburgh Penguins", "Year": 2000, "Wins": 42, "Losses": 28, "Win %": 0.412, "GF": 281, "GA": 256, "Diff": 25},
    {"Team": "San Jose Sharks", "Year": 2000, "Wins": 40, "Losses": 27, "Win %": 0.412, "GF": 217, "GA": 192, "Diff": 25},
    {"Team": "St. Louis Blues", "Year": 2000, "Wins": 43, "Losses": 22, "Win %": 0.412, "GF": 249, "GA": 195, "Diff": 54},
    {"Team": "Tampa Bay Lightning", "Year": 2000, "Wins": 24, "Losses": 47, "Win %": 0.412, "GF": 201, "GA": 280, "Diff": -79},
    {"Team": "Toronto Maple Leafs", "Year": 2000, "Wins": 37, "Losses": 29, "Win %": 0.412, "GF": 232, "GA": 207, "Diff": 25},
    {"Team": "Vancouver Canucks", "Year": 2000, "Wins": 36, "Losses": 28, "Win %": 0.412, "GF": 239, "GA": 238, "Diff": 1},
    {"Team": "Washington Capitals", "Year": 2000, "Wins": 41, "Losses": 27, "Win %": 0.412, "GF": 233, "GA": 211, "Diff": 22},
]

# Vytvoření DataFrame
df = pd.DataFrame(data)

# Nastavení možností pro úplné zobrazení
pd.set_option('display.max_rows', None)
pd.set_option('display.width', 1000)

# Výpis DataFrame
print(df)
# Out:
#                        Team  Year  Wins  Losses  Win %   GF   GA  Diff
# 0   Mighty Ducks of Anaheim  2000    25      41  0.412  188  245   -57
# 1         Atlanta Thrashers  2000    23      45  0.412  211  289   -78
# 2             Boston Bruins  2000    36      30  0.412  227  249   -22
# 3            Buffalo Sabres  2000    46      30  0.412  218  184    34
# 4            Calgary Flames  2000    27      36  0.412  197  236   -39
# 5       Carolina Hurricanes  2000    38      32  0.412  212  225   -13
# 6     Columbus Blue Jackets  2000    28      39  0.412  190  233   -43
# 7        Chicago Blackhawks  2000    29      40  0.412  210  246   -36
# 8        Colorado Avalanche  2000    52      16  0.412  270  192    78
# 9              Dallas Stars  2000    48      24  0.412  241  187    54
# 10        Detroit Red Wings  2000    49      20  0.412  253  202    51
# 11          Edmonton Oilers  2000    39      28  0.412  243  222    21
# ...

# %% [markdown]
# <big><big><big><span style="color:orange; font-weight:bold;">2001</span>

# %%
from bs4 import BeautifulSoup
import requests
import time

url = "https://www.scrapethissite.com/pages/forms/?per_page=400"

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/115.0.0.0 Safari/537.36'
}

response = requests.get(url, headers=headers)
time.sleep(1)  # Jedna sekunda, aby server nebyl přetížen

# Pokud je stránka dostupná
if response.status_code == 200:
    soup = BeautifulSoup(response.text, 'html.parser')

    # Vyhledání všech řádků s třídou "team" 
    teams = soup.find_all('tr', class_='team')
    
    # Pro každý tým extrahujeme data
    for team in teams:
        year = team.find('td', class_='year').text.strip()
        
        if year == '2001':
            name = team.find('td', class_='name').text.strip()
            wins = team.find('td', class_='wins').text.strip()
            losses = team.find('td', class_='losses').text.strip()
            goals_for = team.find('td', class_='gf').text.strip()  # goly vstřelené
            goals_against = team.find('td', class_='ga').text.strip()  # Góly obdržené
            diff = team.find('td', class_='diff').text.strip()  # Rozdíl skóre

            # Výpis dat pouze pro rok 1990
            print(f"Team: {name}, Year: {year}, Wins: {wins}, Losses: {losses}, Win %: {win_pct}, GF: {goals_for}, GA: {goals_against}, Diff: {diff}")
else:
    print("Chyba při načítání stránky:", response.status_code)
# Out:
# Team: Mighty Ducks of Anaheim, Year: 2001, Wins: 29, Losses: 42, Win %: 0.412, GF: 175, GA: 198, Diff: -23
# Team: Atlanta Thrashers, Year: 2001, Wins: 19, Losses: 47, Win %: 0.412, GF: 187, GA: 288, Diff: -101
# Team: Boston Bruins, Year: 2001, Wins: 43, Losses: 24, Win %: 0.412, GF: 236, GA: 201, Diff: 35
# Team: Buffalo Sabres, Year: 2001, Wins: 35, Losses: 35, Win %: 0.412, GF: 213, GA: 200, Diff: 13
# Team: Calgary Flames, Year: 2001, Wins: 32, Losses: 35, Win %: 0.412, GF: 201, GA: 220, Diff: -19
# Team: Carolina Hurricanes, Year: 2001, Wins: 35, Losses: 26, Win %: 0.412, GF: 217, GA: 217, Diff: 0
# Team: Columbus Blue Jackets, Year: 2001, Wins: 22, Losses: 47, Win %: 0.412, GF: 164, GA: 255, Diff: -91
# Team: Chicago Blackhawks, Year: 2001, Wins: 41, Losses: 27, Win %: 0.412, GF: 216, GA: 207, Diff: 9
# Team: Colorado Avalanche, Year: 2001, Wins: 45, Losses: 28, Win %: 0.412, GF: 212, GA: 169, Diff: 43
# ...

# %%
import pandas as pd

data = [
    {"Team": "Mighty Ducks of Anaheim", "Year": 2001, "Wins": 29, "Losses": 42, "Win %": 0.412, "GF": 175, "GA": 198, "Diff": -23},
    {"Team": "Atlanta Thrashers", "Year": 2001, "Wins": 19, "Losses": 47, "Win %": 0.412, "GF": 187, "GA": 288, "Diff": -101},
    {"Team": "Boston Bruins", "Year": 2001, "Wins": 43, "Losses": 24, "Win %": 0.412, "GF": 236, "GA": 201, "Diff": 35},
    {"Team": "Buffalo Sabres", "Year": 2001, "Wins": 35, "Losses": 35, "Win %": 0.412, "GF": 213, "GA": 200, "Diff": 13},
    {"Team": "Calgary Flames", "Year": 2001, "Wins": 32, "Losses": 35, "Win %": 0.412, "GF": 201, "GA": 220, "Diff": -19},
    {"Team": "Carolina Hurricanes", "Year": 2001, "Wins": 35, "Losses": 26, "Win %": 0.412, "GF": 217, "GA": 217, "Diff": 0},
    {"Team": "Columbus Blue Jackets", "Year": 2001, "Wins": 22, "Losses": 47, "Win %": 0.412, "GF": 164, "GA": 255, "Diff": -91},
    {"Team": "Chicago Blackhawks", "Year": 2001, "Wins": 41, "Losses": 27, "Win %": 0.412, "GF": 216, "GA": 207, "Diff": 9},
    {"Team": "Colorado Avalanche", "Year": 2001, "Wins": 45, "Losses": 28, "Win %": 0.412, "GF": 212, "GA": 169, "Diff": 43},
    {"Team": "Dallas Stars", "Year": 2001, "Wins": 36, "Losses": 28, "Win %": 0.412, "GF": 215, "GA": 213, "Diff": 2},
    {"Team": "Detroit Red Wings", "Year": 2001, "Wins": 51, "Losses": 17, "Win %": 0.412, "GF": 251, "GA": 187, "Diff": 64},
    {"Team": "Edmonton Oilers", "Year": 2001, "Wins": 38, "Losses": 28, "Win %": 0.412, "GF": 205, "GA": 182, "Diff": 23},
    {"Team": "Florida Panthers", "Year": 2001, "Wins": 22, "Losses": 44, "Win %": 0.412, "GF": 180, "GA": 250, "Diff": -70},
    {"Team": "Los Angeles Kings", "Year": 2001, "Wins": 40, "Losses": 27, "Win %": 0.412, "GF": 214, "GA": 190, "Diff": 24},
    {"Team": "Minnesota Wild", "Year": 2001, "Wins": 26, "Losses": 35, "Win %": 0.412, "GF": 195, "GA": 238, "Diff": -43},
    {"Team": "Montreal Canadiens", "Year": 2001, "Wins": 36, "Losses": 31, "Win %": 0.412, "GF": 207, "GA": 209, "Diff": -2},
    {"Team": "Nashville Predators", "Year": 2001, "Wins": 28, "Losses": 41, "Win %": 0.412, "GF": 196, "GA": 230, "Diff": -34},
    {"Team": "New Jersey Devils", "Year": 2001, "Wins": 41, "Losses": 28, "Win %": 0.412, "GF": 205, "GA": 187, "Diff": 18},
    {"Team": "New York Islanders", "Year": 2001, "Wins": 42, "Losses": 28, "Win %": 0.412, "GF": 239, "GA": 220, "Diff": 19},
    {"Team": "New York Rangers", "Year": 2001, "Wins": 36, "Losses": 38, "Win %": 0.412, "GF": 227, "GA": 258, "Diff": -31},
    {"Team": "Ottawa Senators", "Year": 2001, "Wins": 39, "Losses": 27, "Win %": 0.412, "GF": 243, "GA": 208, "Diff": 35},
    {"Team": "Philadelphia Flyers", "Year": 2001, "Wins": 42, "Losses": 27, "Win %": 0.412, "GF": 234, "GA": 192, "Diff": 42},
    {"Team": "Phoenix Coyotes", "Year": 2001, "Wins": 40, "Losses": 27, "Win %": 0.412, "GF": 228, "GA": 210, "Diff": 18},
    {"Team": "Pittsburgh Penguins", "Year": 2001, "Wins": 28, "Losses": 41, "Win %": 0.412, "GF": 198, "GA": 249, "Diff": -51},
    {"Team": "San Jose Sharks", "Year": 2001, "Wins": 44, "Losses": 27, "Win %": 0.412, "GF": 248, "GA": 199, "Diff": 49},
    {"Team": "St. Louis Blues", "Year": 2001, "Wins": 43, "Losses": 27, "Win %": 0.412, "GF": 227, "GA": 188, "Diff": 39},
    {"Team": "Tampa Bay Lightning", "Year": 2001, "Wins": 27, "Losses": 40, "Win %": 0.412, "GF": 178, "GA": 219, "Diff": -41},
    {"Team": "Toronto Maple Leafs", "Year": 2001, "Wins": 43, "Losses": 25, "Win %": 0.412, "GF": 249, "GA": 207, "Diff": 42},
    {"Team": "Vancouver Canucks", "Year": 2001, "Wins": 42, "Losses": 30, "Win %": 0.412, "GF": 254, "GA": 211, "Diff": 43},
    {"Team": "Washington Capitals", "Year": 2001, "Wins": 36, "Losses": 33, "Win %": 0.412, "GF": 228, "GA": 240, "Diff": -12},
]

# Vytvoření DataFrame
df = pd.DataFrame(data)

# Nastavení možností pro úplné zobrazení
pd.set_option('display.max_rows', None)
pd.set_option('display.width', 1000)

# Výpis DataFrame
print(df)

# Uložení do CSV
df.to_csv('nhl_data_2001.csv', index=False)
# Out:
#                        Team  Year  Wins  Losses  Win %   GF   GA  Diff
# 0   Mighty Ducks of Anaheim  2001    29      42  0.412  175  198   -23
# 1         Atlanta Thrashers  2001    19      47  0.412  187  288  -101
# 2             Boston Bruins  2001    43      24  0.412  236  201    35
# 3            Buffalo Sabres  2001    35      35  0.412  213  200    13
# 4            Calgary Flames  2001    32      35  0.412  201  220   -19
# 5       Carolina Hurricanes  2001    35      26  0.412  217  217     0
# 6     Columbus Blue Jackets  2001    22      47  0.412  164  255   -91
# 7        Chicago Blackhawks  2001    41      27  0.412  216  207     9
# 8        Colorado Avalanche  2001    45      28  0.412  212  169    43
# 9              Dallas Stars  2001    36      28  0.412  215  213     2
# 10        Detroit Red Wings  2001    51      17  0.412  251  187    64
# 11          Edmonton Oilers  2001    38      28  0.412  205  182    23
# ...

# %% [markdown]
# <big><big><big><span style="color:orange; font-weight:bold;">2002</span>

# %%
from bs4 import BeautifulSoup
import requests
import time

url = "https://www.scrapethissite.com/pages/forms/?per_page=400"

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/115.0.0.0 Safari/537.36'
}

response = requests.get(url, headers=headers)
time.sleep(1)  # Jedna sekunda, aby server nebyl přetížen

# Pokud je stránka dostupná
if response.status_code == 200:
    soup = BeautifulSoup(response.text, 'html.parser')

    # Vyhledání všech řádků s třídou "team" 
    teams = soup.find_all('tr', class_='team')
    
    # Pro každý tým extrahujeme data
    for team in teams:
        year = team.find('td', class_='year').text.strip()
        
        if year == '2002':
            name = team.find('td', class_='name').text.strip()
            wins = team.find('td', class_='wins').text.strip()
            losses = team.find('td', class_='losses').text.strip()
            goals_for = team.find('td', class_='gf').text.strip()  # goly vstřelené
            goals_against = team.find('td', class_='ga').text.strip()  # Góly obdržené
            diff = team.find('td', class_='diff').text.strip()  # Rozdíl skóre

            # Výpis dat pouze pro rok 1990
            print(f"Team: {name}, Year: {year}, Wins: {wins}, Losses: {losses}, GF: {goals_for}, GA: {goals_against}, Diff: {diff}")
else:
    print("Chyba při načítání stránky:", response.status_code)
# Out:
# Team: Mighty Ducks of Anaheim, Year: 2002, Wins: 40, Losses: 27, GF: 203, GA: 193, Diff: 10
# Team: Atlanta Thrashers, Year: 2002, Wins: 31, Losses: 39, GF: 226, GA: 284, Diff: -58
# Team: Boston Bruins, Year: 2002, Wins: 36, Losses: 31, GF: 245, GA: 237, Diff: 8
# Team: Buffalo Sabres, Year: 2002, Wins: 27, Losses: 37, GF: 190, GA: 219, Diff: -29
# Team: Calgary Flames, Year: 2002, Wins: 29, Losses: 36, GF: 186, GA: 228, Diff: -42
# Team: Carolina Hurricanes, Year: 2002, Wins: 22, Losses: 43, GF: 171, GA: 240, Diff: -69
# Team: Columbus Blue Jackets, Year: 2002, Wins: 29, Losses: 42, GF: 213, GA: 263, Diff: -50
# Team: Chicago Blackhawks, Year: 2002, Wins: 30, Losses: 33, GF: 207, GA: 226, Diff: -19
# Team: Colorado Avalanche, Year: 2002, Wins: 42, Losses: 19, GF: 251, GA: 194, Diff: 57
# Team: Dallas Stars, Year: 2002, Wins: 46, Losses: 17, GF: 245, GA: 169, Diff: 76
# Team: Detroit Red Wings, Year: 2002, Wins: 48, Losses: 20, GF: 269, GA: 203, Diff: 66
# ...

# %%
import pandas as pd

data = [
    {"Team": "Mighty Ducks of Anaheim", "Year": 2002, "Wins": 40, "Losses": 27, "GF": 203, "GA": 193, "Diff": 10},
    {"Team": "Atlanta Thrashers", "Year": 2002, "Wins": 31, "Losses": 39, "GF": 226, "GA": 284, "Diff": -58},
    {"Team": "Boston Bruins", "Year": 2002, "Wins": 36, "Losses": 31, "GF": 245, "GA": 237, "Diff": 8},
    {"Team": "Buffalo Sabres", "Year": 2002, "Wins": 27, "Losses": 37, "GF": 190, "GA": 219, "Diff": -29},
    {"Team": "Calgary Flames", "Year": 2002, "Wins": 29, "Losses": 36, "GF": 186, "GA": 228, "Diff": -42},
    {"Team": "Carolina Hurricanes", "Year": 2002, "Wins": 22, "Losses": 43, "GF": 171, "GA": 240, "Diff": -69},
    {"Team": "Columbus Blue Jackets", "Year": 2002, "Wins": 29, "Losses": 42, "GF": 213, "GA": 263, "Diff": -50},
    {"Team": "Chicago Blackhawks", "Year": 2002, "Wins": 30, "Losses": 33, "GF": 207, "GA": 226, "Diff": -19},
    {"Team": "Colorado Avalanche", "Year": 2002, "Wins": 42, "Losses": 19, "GF": 251, "GA": 194, "Diff": 57},
    {"Team": "Dallas Stars", "Year": 2002, "Wins": 46, "Losses": 17, "GF": 245, "GA": 169, "Diff": 76},
    {"Team": "Detroit Red Wings", "Year": 2002, "Wins": 48, "Losses": 20, "GF": 269, "GA": 203, "Diff": 66},
    {"Team": "Edmonton Oilers", "Year": 2002, "Wins": 36, "Losses": 26, "GF": 231, "GA": 230, "Diff": 1},
    {"Team": "Florida Panthers", "Year": 2002, "Wins": 24, "Losses": 36, "GF": 176, "GA": 237, "Diff": -61},
    {"Team": "Los Angeles Kings", "Year": 2002, "Wins": 33, "Losses": 37, "GF": 203, "GA": 221, "Diff": -18},
    {"Team": "Minnesota Wild", "Year": 2002, "Wins": 42, "Losses": 29, "GF": 198, "GA": 178, "Diff": 20},
    {"Team": "Montreal Canadiens", "Year": 2002, "Wins": 30, "Losses": 35, "GF": 206, "GA": 234, "Diff": -28},
    {"Team": "Nashville Predators", "Year": 2002, "Wins": 27, "Losses": 35, "GF": 183, "GA": 206, "Diff": -23},
    {"Team": "New Jersey Devils", "Year": 2002, "Wins": 46, "Losses": 20, "GF": 216, "GA": 166, "Diff": 50},
    {"Team": "New York Islanders", "Year": 2002, "Wins": 35, "Losses": 34, "GF": 224, "GA": 231, "Diff": -7},
    {"Team": "New York Rangers", "Year": 2002, "Wins": 32, "Losses": 36, "GF": 210, "GA": 231, "Diff": -21},
    {"Team": "Ottawa Senators", "Year": 2002, "Wins": 52, "Losses": 21, "GF": 263, "GA": 182, "Diff": 81},
    {"Team": "Philadelphia Flyers", "Year": 2002, "Wins": 45, "Losses": 20, "GF": 211, "GA": 166, "Diff": 45},
    {"Team": "Phoenix Coyotes", "Year": 2002, "Wins": 31, "Losses": 35, "GF": 204, "GA": 230, "Diff": -26},
    {"Team": "Pittsburgh Penguins", "Year": 2002, "Wins": 27, "Losses": 44, "GF": 189, "GA": 255, "Diff": -66},
    {"Team": "San Jose Sharks", "Year": 2002, "Wins": 28, "Losses": 37, "GF": 214, "GA": 239, "Diff": -25},
    {"Team": "St. Louis Blues", "Year": 2002, "Wins": 41, "Losses": 24, "GF": 253, "GA": 222, "Diff": 31},
    {"Team": "Tampa Bay Lightning", "Year": 2002, "Wins": 36, "Losses": 25, "GF": 219, "GA": 210, "Diff": 9},
    {"Team": "Toronto Maple Leafs", "Year": 2002, "Wins": 44, "Losses": 28, "GF": 236, "GA": 208, "Diff": 28},
    {"Team": "Vancouver Canucks", "Year": 2002, "Wins": 45, "Losses": 23, "GF": 264, "GA": 208, "Diff": 56},
    {"Team": "Washington Capitals", "Year": 2002, "Wins": 39, "Losses": 29, "GF": 224, "GA": 220, "Diff": 4},
]

# Vytvoření DataFrame
df = pd.DataFrame(data)

# Nastavení možností pro úplné zobrazení
pd.set_option('display.max_rows', None)
pd.set_option('display.width', 1000)

# Výpis DataFrame
print(df)

# Uložení do CSV
df.to_csv('nhl_data_2002.csv', index=False)
# Out:
#                        Team  Year  Wins  Losses   GF   GA  Diff
# 0   Mighty Ducks of Anaheim  2002    40      27  203  193    10
# 1         Atlanta Thrashers  2002    31      39  226  284   -58
# 2             Boston Bruins  2002    36      31  245  237     8
# 3            Buffalo Sabres  2002    27      37  190  219   -29
# 4            Calgary Flames  2002    29      36  186  228   -42
# 5       Carolina Hurricanes  2002    22      43  171  240   -69
# 6     Columbus Blue Jackets  2002    29      42  213  263   -50
# 7        Chicago Blackhawks  2002    30      33  207  226   -19
# 8        Colorado Avalanche  2002    42      19  251  194    57
# 9              Dallas Stars  2002    46      17  245  169    76
# 10        Detroit Red Wings  2002    48      20  269  203    66
# 11          Edmonton Oilers  2002    36      26  231  230     1
# 12         Florida Panthers  2002    24      36  176  237   -61
# 13        Los Angeles Kings  2002    33      37  203  221   -18
# ...

# %% [markdown]
# <big><big><big><span style="color:orange; font-weight:bold;">2003</span>

# %%
from bs4 import BeautifulSoup
import requests
import time

url = "https://www.scrapethissite.com/pages/forms/?per_page=400"

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/115.0.0.0 Safari/537.36'
}

response = requests.get(url, headers=headers)
time.sleep(1)  # Jedna sekunda, aby server nebyl přetížen

# Pokud je stránka dostupná
if response.status_code == 200:
    soup = BeautifulSoup(response.text, 'html.parser')

    # Vyhledání všech řádků s třídou "team" 
    teams = soup.find_all('tr', class_='team')
    
    # Pro každý tým extrahujeme data
    for team in teams:
        year = team.find('td', class_='year').text.strip()
        
        if year == '2003':
            name = team.find('td', class_='name').text.strip()
            wins = team.find('td', class_='wins').text.strip()
            losses = team.find('td', class_='losses').text.strip()
            goals_for = team.find('td', class_='gf').text.strip()  # goly vstřelené
            goals_against = team.find('td', class_='ga').text.strip()  # Góly obdržené
            diff = team.find('td', class_='diff').text.strip()  # Rozdíl skóre

            # Výpis dat pouze pro rok 1990
            print(f"Team: {name}, Year: {year}, Wins: {wins}, Losses: {losses}, GF: {goals_for}, GA: {goals_against}, Diff: {diff}")
else:
    print("Chyba při načítání stránky:", response.status_code)
# Out:
# Team: Mighty Ducks of Anaheim, Year: 2003, Wins: 29, Losses: 35, GF: 184, GA: 213, Diff: -29
# Team: Atlanta Thrashers, Year: 2003, Wins: 33, Losses: 37, GF: 214, GA: 243, Diff: -29
# Team: Boston Bruins, Year: 2003, Wins: 41, Losses: 19, GF: 209, GA: 188, Diff: 21
# Team: Buffalo Sabres, Year: 2003, Wins: 37, Losses: 34, GF: 220, GA: 221, Diff: -1
# Team: Calgary Flames, Year: 2003, Wins: 42, Losses: 30, GF: 200, GA: 176, Diff: 24
# Team: Carolina Hurricanes, Year: 2003, Wins: 28, Losses: 34, GF: 172, GA: 209, Diff: -37
# Team: Columbus Blue Jackets, Year: 2003, Wins: 25, Losses: 45, GF: 177, GA: 238, Diff: -61
# Team: Chicago Blackhawks, Year: 2003, Wins: 20, Losses: 43, GF: 188, GA: 259, Diff: -71
# Team: Colorado Avalanche, Year: 2003, Wins: 40, Losses: 22, GF: 236, GA: 198, Diff: 38
# Team: Dallas Stars, Year: 2003, Wins: 41, Losses: 26, GF: 194, GA: 175, Diff: 19
# Team: Detroit Red Wings, Year: 2003, Wins: 48, Losses: 21, GF: 255, GA: 189, Diff: 66
# ...

# %%
import pandas as pd

data = [
    {"Team": "Mighty Ducks of Anaheim", "Year": 2003, "Wins": 29, "Losses": 35, "GF": 184, "GA": 213, "Diff": -29},
    {"Team": "Atlanta Thrashers", "Year": 2003, "Wins": 33, "Losses": 37, "GF": 214, "GA": 243, "Diff": -29},
    {"Team": "Boston Bruins", "Year": 2003, "Wins": 41, "Losses": 19, "GF": 209, "GA": 188, "Diff": 21},
    {"Team": "Buffalo Sabres", "Year": 2003, "Wins": 37, "Losses": 34, "GF": 220, "GA": 221, "Diff": -1},
    {"Team": "Calgary Flames", "Year": 2003, "Wins": 42, "Losses": 30, "GF": 200, "GA": 176, "Diff": 24},
    {"Team": "Carolina Hurricanes", "Year": 2003, "Wins": 28, "Losses": 34, "GF": 172, "GA": 209, "Diff": -37},
    {"Team": "Columbus Blue Jackets", "Year": 2003, "Wins": 25, "Losses": 45, "GF": 177, "GA": 238, "Diff": -61},
    {"Team": "Chicago Blackhawks", "Year": 2003, "Wins": 20, "Losses": 43, "GF": 188, "GA": 259, "Diff": -71},
    {"Team": "Colorado Avalanche", "Year": 2003, "Wins": 40, "Losses": 22, "GF": 236, "GA": 198, "Diff": 38},
    {"Team": "Dallas Stars", "Year": 2003, "Wins": 41, "Losses": 26, "GF": 194, "GA": 175, "Diff": 19},
    {"Team": "Detroit Red Wings", "Year": 2003, "Wins": 48, "Losses": 21, "GF": 255, "GA": 189, "Diff": 66},
    {"Team": "Edmonton Oilers", "Year": 2003, "Wins": 36, "Losses": 29, "GF": 221, "GA": 208, "Diff": 13},
    {"Team": "Florida Panthers", "Year": 2003, "Wins": 28, "Losses": 35, "GF": 188, "GA": 221, "Diff": -33},
    {"Team": "Los Angeles Kings", "Year": 2003, "Wins": 28, "Losses": 29, "GF": 205, "GA": 217, "Diff": -12},
    {"Team": "Minnesota Wild", "Year": 2003, "Wins": 30, "Losses": 29, "GF": 188, "GA": 183, "Diff": 5},
    {"Team": "Montreal Canadiens", "Year": 2003, "Wins": 41, "Losses": 30, "GF": 208, "GA": 192, "Diff": 16},
    {"Team": "Nashville Predators", "Year": 2003, "Wins": 38, "Losses": 29, "GF": 216, "GA": 217, "Diff": -1},
    {"Team": "New Jersey Devils", "Year": 2003, "Wins": 43, "Losses": 25, "GF": 213, "GA": 164, "Diff": 49},
    {"Team": "New York Islanders", "Year": 2003, "Wins": 38, "Losses": 29, "GF": 237, "GA": 210, "Diff": 27},
    {"Team": "New York Rangers", "Year": 2003, "Wins": 27, "Losses": 40, "GF": 206, "GA": 250, "Diff": -44},
    {"Team": "Ottawa Senators", "Year": 2003, "Wins": 43, "Losses": 23, "GF": 262, "GA": 189, "Diff": 73},
    {"Team": "Philadelphia Flyers", "Year": 2003, "Wins": 40, "Losses": 21, "GF": 229, "GA": 186, "Diff": 43},
    {"Team": "Phoenix Coyotes", "Year": 2003, "Wins": 22, "Losses": 36, "GF": 188, "GA": 245, "Diff": -57},
    {"Team": "Pittsburgh Penguins", "Year": 2003, "Wins": 23, "Losses": 47, "GF": 190, "GA": 303, "Diff": -113},
    {"Team": "San Jose Sharks", "Year": 2003, "Wins": 43, "Losses": 21, "GF": 219, "GA": 183, "Diff": 36},
    {"Team": "St. Louis Blues", "Year": 2003, "Wins": 39, "Losses": 30, "GF": 191, "GA": 198, "Diff": -7},
    {"Team": "Tampa Bay Lightning", "Year": 2003, "Wins": 46, "Losses": 22, "GF": 245, "GA": 192, "Diff": 53},
    {"Team": "Toronto Maple Leafs", "Year": 2003, "Wins": 45, "Losses": 24, "GF": 242, "GA": 204, "Diff": 38},
    {"Team": "Vancouver Canucks", "Year": 2003, "Wins": 43, "Losses": 24, "GF": 235, "GA": 194, "Diff": 41},
    {"Team": "Washington Capitals", "Year": 2003, "Wins": 23, "Losses": 46, "GF": 186, "GA": 253, "Diff": -67},
]

# Vytvoření DataFrame
df = pd.DataFrame(data)

# Nastavení možností pro úplné zobrazení
pd.set_option('display.max_rows', None)
pd.set_option('display.width', 1000)

# Výpis DataFrame
print(df)

# Uložení do CSV
df.to_csv('nhl_data_2003.csv', index=False)
# Out:
#                        Team  Year  Wins  Losses   GF   GA  Diff
# 0   Mighty Ducks of Anaheim  2003    29      35  184  213   -29
# 1         Atlanta Thrashers  2003    33      37  214  243   -29
# 2             Boston Bruins  2003    41      19  209  188    21
# 3            Buffalo Sabres  2003    37      34  220  221    -1
# 4            Calgary Flames  2003    42      30  200  176    24
# 5       Carolina Hurricanes  2003    28      34  172  209   -37
# 6     Columbus Blue Jackets  2003    25      45  177  238   -61
# 7        Chicago Blackhawks  2003    20      43  188  259   -71
# 8        Colorado Avalanche  2003    40      22  236  198    38
# 9              Dallas Stars  2003    41      26  194  175    19
# 10        Detroit Red Wings  2003    48      21  255  189    66
# 11          Edmonton Oilers  2003    36      29  221  208    13
# 12         Florida Panthers  2003    28      35  188  221   -33
# 13        Los Angeles Kings  2003    28      29  205  217   -12
# ...

# %% [markdown]
# <big><big><big><span style="color:orange; font-weight:bold;">2005</span>

# %%
from bs4 import BeautifulSoup
import requests
import time

url = "https://www.scrapethissite.com/pages/forms/?per_page=700"

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/115.0.0.0 Safari/537.36'
}

response = requests.get(url, headers=headers)
time.sleep(1)  # Jedna sekunda, aby server nebyl přetížen

# Pokud je stránka dostupná
if response.status_code == 200:
    soup = BeautifulSoup(response.text, 'html.parser')

    # Vyhledání všech řádků s třídou "team" 
    teams = soup.find_all('tr', class_='team')
    
    # Pro každý tým extrahujeme data
    for team in teams:
        year = team.find('td', class_='year').text.strip()
        
        if year == '2005':
            name = team.find('td', class_='name').text.strip()
            wins = team.find('td', class_='wins').text.strip()
            losses = team.find('td', class_='losses').text.strip()
            goals_for = team.find('td', class_='gf').text.strip()  # goly vstřelené
            goals_against = team.find('td', class_='ga').text.strip()  # Góly obdržené
            diff = team.find('td', class_='diff').text.strip()  # Rozdíl skóre

            # Výpis dat pouze pro rok 1990
            print(f"Team: {name}, Year: {year}, Wins: {wins}, Losses: {losses}, GF: {goals_for}, GA: {goals_against}, Diff: {diff}")
else:
    print("Chyba při načítání stránky:", response.status_code)
# Out:
# Team: Mighty Ducks of Anaheim, Year: 2005, Wins: 43, Losses: 27, GF: 254, GA: 229, Diff: 25
# Team: Atlanta Thrashers, Year: 2005, Wins: 41, Losses: 33, GF: 281, GA: 275, Diff: 6
# Team: Boston Bruins, Year: 2005, Wins: 29, Losses: 37, GF: 230, GA: 266, Diff: -36
# Team: Buffalo Sabres, Year: 2005, Wins: 52, Losses: 24, GF: 281, GA: 239, Diff: 42
# Team: Calgary Flames, Year: 2005, Wins: 46, Losses: 25, GF: 218, GA: 200, Diff: 18
# Team: Carolina Hurricanes, Year: 2005, Wins: 52, Losses: 22, GF: 294, GA: 260, Diff: 34
# Team: Columbus Blue Jackets, Year: 2005, Wins: 35, Losses: 43, GF: 223, GA: 279, Diff: -56
# Team: Chicago Blackhawks, Year: 2005, Wins: 26, Losses: 43, GF: 211, GA: 285, Diff: -74
# Team: Colorado Avalanche, Year: 2005, Wins: 43, Losses: 30, GF: 283, GA: 257, Diff: 26
# Team: Dallas Stars, Year: 2005, Wins: 53, Losses: 23, GF: 265, GA: 218, Diff: 47
# Team: Detroit Red Wings, Year: 2005, Wins: 58, Losses: 16, GF: 305, GA: 209, Diff: 96
# ...

# %%
import pandas as pd

data = [
    {"Team": "Mighty Ducks of Anaheim", "Year": 2005, "Wins": 43, "Losses": 27, "GF": 254, "GA": 229, "Diff": 25},
    {"Team": "Atlanta Thrashers", "Year": 2005, "Wins": 41, "Losses": 33, "GF": 281, "GA": 275, "Diff": 6},
    {"Team": "Boston Bruins", "Year": 2005, "Wins": 29, "Losses": 37, "GF": 230, "GA": 266, "Diff": -36},
    {"Team": "Buffalo Sabres", "Year": 2005, "Wins": 52, "Losses": 24, "GF": 281, "GA": 239, "Diff": 42},
    {"Team": "Calgary Flames", "Year": 2005, "Wins": 46, "Losses": 25, "GF": 218, "GA": 200, "Diff": 18},
    {"Team": "Carolina Hurricanes", "Year": 2005, "Wins": 52, "Losses": 22, "GF": 294, "GA": 260, "Diff": 34},
    {"Team": "Columbus Blue Jackets", "Year": 2005, "Wins": 35, "Losses": 43, "GF": 223, "GA": 279, "Diff": -56},
    {"Team": "Chicago Blackhawks", "Year": 2005, "Wins": 26, "Losses": 43, "GF": 211, "GA": 285, "Diff": -74},
    {"Team": "Colorado Avalanche", "Year": 2005, "Wins": 43, "Losses": 30, "GF": 283, "GA": 257, "Diff": 26},
    {"Team": "Dallas Stars", "Year": 2005, "Wins": 53, "Losses": 23, "GF": 265, "GA": 218, "Diff": 47},
    {"Team": "Detroit Red Wings", "Year": 2005, "Wins": 58, "Losses": 16, "GF": 305, "GA": 209, "Diff": 96},
    {"Team": "Edmonton Oilers", "Year": 2005, "Wins": 41, "Losses": 28, "GF": 256, "GA": 251, "Diff": 5},
    {"Team": "Florida Panthers", "Year": 2005, "Wins": 37, "Losses": 34, "GF": 240, "GA": 257, "Diff": -17},
    {"Team": "Los Angeles Kings", "Year": 2005, "Wins": 42, "Losses": 35, "GF": 249, "GA": 270, "Diff": -21},
    {"Team": "Minnesota Wild", "Year": 2005, "Wins": 38, "Losses": 36, "GF": 231, "GA": 215, "Diff": 16},
    {"Team": "Montreal Canadiens", "Year": 2005, "Wins": 42, "Losses": 31, "GF": 243, "GA": 247, "Diff": -4},
    {"Team": "Nashville Predators", "Year": 2005, "Wins": 49, "Losses": 25, "GF": 259, "GA": 227, "Diff": 32},
    {"Team": "New Jersey Devils", "Year": 2005, "Wins": 46, "Losses": 27, "GF": 242, "GA": 229, "Diff": 13},
    {"Team": "New York Islanders", "Year": 2005, "Wins": 36, "Losses": 40, "GF": 230, "GA": 278, "Diff": -48},
    {"Team": "New York Rangers", "Year": 2005, "Wins": 44, "Losses": 26, "GF": 257, "GA": 215, "Diff": 42},
    {"Team": "Ottawa Senators", "Year": 2005, "Wins": 52, "Losses": 21, "GF": 314, "GA": 211, "Diff": 103},
    {"Team": "Philadelphia Flyers", "Year": 2005, "Wins": 45, "Losses": 26, "GF": 267, "GA": 259, "Diff": 8},
    {"Team": "Phoenix Coyotes", "Year": 2005, "Wins": 38, "Losses": 39, "GF": 246, "GA": 271, "Diff": -25},
    {"Team": "Pittsburgh Penguins", "Year": 2005, "Wins": 22, "Losses": 46, "GF": 244, "GA": 316, "Diff": -72},
    {"Team": "San Jose Sharks", "Year": 2005, "Wins": 44, "Losses": 27, "GF": 266, "GA": 242, "Diff": 24},
    {"Team": "St. Louis Blues", "Year": 2005, "Wins": 21, "Losses": 46, "GF": 197, "GA": 292, "Diff": -95},
    {"Team": "Tampa Bay Lightning", "Year": 2005, "Wins": 43, "Losses": 33, "GF": 252, "GA": 260, "Diff": -8},
    {"Team": "Toronto Maple Leafs", "Year": 2005, "Wins": 41, "Losses": 33, "GF": 257, "GA": 270, "Diff": -13},
    {"Team": "Vancouver Canucks", "Year": 2005, "Wins": 42, "Losses": 32, "GF": 256, "GA": 255, "Diff": 1},
    {"Team": "Washington Capitals", "Year": 2005, "Wins": 29, "Losses": 41, "GF": 237, "GA": 306, "Diff": -69},
]

# Vytvoření DataFrame
df = pd.DataFrame(data)

# Nastavení možností pro úplné zobrazení
pd.set_option('display.max_rows', None)
pd.set_option('display.width', 1000)

# Výpis DataFrame
print(df)
# Out:
#                        Team  Year  Wins  Losses   GF   GA  Diff
# 0   Mighty Ducks of Anaheim  2005    43      27  254  229    25
# 1         Atlanta Thrashers  2005    41      33  281  275     6
# 2             Boston Bruins  2005    29      37  230  266   -36
# 3            Buffalo Sabres  2005    52      24  281  239    42
# 4            Calgary Flames  2005    46      25  218  200    18
# 5       Carolina Hurricanes  2005    52      22  294  260    34
# 6     Columbus Blue Jackets  2005    35      43  223  279   -56
# 7        Chicago Blackhawks  2005    26      43  211  285   -74
# 8        Colorado Avalanche  2005    43      30  283  257    26
# 9              Dallas Stars  2005    53      23  265  218    47
# 10        Detroit Red Wings  2005    58      16  305  209    96
# 11          Edmonton Oilers  2005    41      28  256  251     5
# 12         Florida Panthers  2005    37      34  240  257   -17
# 13        Los Angeles Kings  2005    42      35  249  270   -21
# ...
