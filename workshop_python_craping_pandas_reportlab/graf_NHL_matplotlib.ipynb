# %%
import pandas as pd
import matplotlib.pyplot as plt

#Data mezi lety 1990 a 2000

data = [
    {"Team": "Chicago Blackhawks", "Year": 1990, "Wins": 49, "Losses": 23, "Win %": 0.613, "GF": 284, "GA": 211, "Diff": 73, "kurzy": 1.0, "umisteni": 1},
    {"Team": "Chicago Blackhawks", "Year": 1991, "Wins": 36, "Losses": 29, "Win %": 0.450, "GF": 257, "GA": 236, "Diff": 21, "kurzy": 5.0, "umisteni": 9},
    {"Team": "Chicago Blackhawks", "Year": 1992, "Wins": 47, "Losses": 25, "Win %": 0.560, "GF": 279, "GA": 230, "Diff": 49, "kurzy": 2.5, "umisteni": 4},
    {"Team": "Chicago Blackhawks", "Year": 1993, "Wins": 39, "Losses": 36, "Win %": 0.464, "GF": 254, "GA": 240, "Diff": 14, "kurzy": 7.0, "umisteni": 13},
    {"Team": "Chicago Blackhawks", "Year": 1994, "Wins": 24, "Losses": 19, "Win %": 0.476, "GF": 156, "GA": 115, "Diff": 41, "kurzy": 4.5, "umisteni": 8},
    {"Team": "Chicago Blackhawks", "Year": 1995, "Wins": 40, "Losses": 28, "Win %": 0.476, "GF": 273, "GA": 220, "Diff": 53, "kurzy": 4.5, "umisteni": 8},
    {"Team": "Chicago Blackhawks", "Year": 1996, "Wins": 34, "Losses": 35, "Win %": 0.476, "GF": 223, "GA": 210, "Diff": 13, "kurzy": 8.0, "umisteni": 15},
    {"Team": "Chicago Blackhawks", "Year": 1997, "Wins": 30, "Losses": 39, "Win %": 0.412, "GF": 192, "GA": 199, "Diff": -7, "kurzy": 9.5, "umisteni": 18},
    {"Team": "Chicago Blackhawks", "Year": 1998, "Wins": 29, "Losses": 41, "Win %": 0.412, "GF": 202, "GA": 248, "Diff": -46, "kurzy": 12.0, "umisteni": 23},
    {"Team": "Chicago Blackhawks", "Year": 1999, "Wins": 33, "Losses": 37, "Win %": 0.412, "GF": 242, "GA": 245, "Diff": -3, "kurzy": 10.0, "umisteni": 19},
    {"Team": "Chicago Blackhawks", "Year": 2000, "Wins": 29, "Losses": 40, "Win %": 0.412, "GF": 210, "GA": 246, "Diff": -36, "kurzy": 11.0, "umisteni": 21},
]

df = pd.DataFrame(data)

#Graf 0: vývoj umístění v NHL mezi lety 1990 až 2000 týmu Chicago Blackhawks
plt.figure(figsize=(12,6))
plt.plot(df['Year'], df['umisteni'], label='Wins', marker='o', color='gold')
plt.title('Vývoj umisteni mezi lety 1990 - 2000')
plt.xlabel('Chicago postupně ztrácelo a na vrchol se již nevrátilo')
plt.ylabel('umisteni')
plt.ylim(1)  
plt.gca().invert_yaxis()
plt.legend()
plt.grid(True)
plt.show()

# Graf 1: Vývoj počtu výher a proher
plt.figure(figsize=(12, 6))
plt.plot(df['Year'], df['Wins'], label='Wins', marker='o')
plt.plot(df['Year'], df['Losses'], label='Losses', marker='o')
plt.title('Vývoj výher a proher (1990-2000)')
plt.xlabel('Od roku 1994 se postupně zvyšoval počet proher')
plt.ylabel('Počet')
plt.legend()
plt.grid(True)
plt.show()

#Graf 2: Skóre rozdíl a úspěšnost výher
fig, ax1 = plt.subplots(figsize=(12, 6))
ax1.plot(df['Year'], df['Diff'], label='Goal Difference', color='blue', marker='o')
ax1.set_xlabel('Úspěšnost se postupně snižovala')
ax1.set_ylabel('Rozdíl gólů', color='blue')
ax1.tick_params(axis='y', labelcolor='blue')

ax2 = ax1.twinx()
ax2.plot(df['Year'], df['Win %'], label='Win %', color='green', marker='x')
ax2.set_ylabel('Úspěšnost výher (%)', color='green')
ax2.tick_params(axis='y', labelcolor='green')

fig.suptitle('Vývoj skóre rozdílu a úspěšnosti výher (1990-2000)')
fig.tight_layout()
plt.grid(True)
plt.show()

# Graf 3: Vývoj kurzu
plt.figure(figsize=(12, 6))
plt.plot(df['Year'], df['kurzy'], label='Kurzy', marker='s', color='red')
plt.title('Vývoj kurzů (1990-2000)')
plt.xlabel('Rje vidět jak se kurz na výhru postupně zvyšoval')
plt.ylabel('Kurzy')
plt.gca().invert_yaxis()
plt.grid(True)
plt.legend()
plt.show()
